# %%
#pull in the saved data for main cast total credits

import json

with open('main_credits.txt', 'r') as file:
    main_credits = json.load(file)
    main_credits = {int(id_str): main_credits[id_str] for id_str in main_credits}
    
main_ids=["1748","1749","1750","1751","1752","1753","1754","1755","1214943","1214944"]

with open('main_cast_stars.txt', 'r') as file:
    main_stars = json.load(file)
    main_stars = {int(id_str): main_stars[id_str] for id_str in main_stars}

# %%
import pandas as pd

# %%
#set up the dataframe to hold the main cast data
data_df= {}
data_df=pd.DataFrame(data_df)
data_df["Name"]= ' '
data_df["Job"]= ' '
data_df["Media"]= ' '
data_df["Date"]= ' '
data_df["Genre"]= ' '
data_df["Title"]= ' '
data_df
# Out:
# Empty DataFrame
# Columns: [Name, Job, Media, Date, Genre, Title]
# Index: []

# %%
#load selected data into the dataframe
counter=0
for id in main_ids:
    act_credits=len(main_credits[int(id)]['cast'])
    crew_credits=len(main_credits[int(id)]['crew'])    
    
    for x in range(0, act_credits):
        data_df.set_value(counter,"Name",main_stars[int(id)]['name'] )
        data_df.set_value(counter,'Job','Actor')
        data_df.set_value(counter,'Media',main_credits[int(id)]['cast'][x]['media_type'])
        data_df.set_value(counter,'Genre',main_credits[int(id)]['cast'][x]['genre_ids'])
        if main_credits[int(id)]['cast'][x]['media_type']=="movie":
            data_df.set_value(counter,'Date',main_credits[int(id)]['cast'][x]['release_date'])
            data_df.set_value(counter,'Title',main_credits[int(id)]['cast'][x]['title'])
            
        else:
            data_df.set_value(counter,'Date',main_credits[int(id)]['cast'][x]['first_air_date'])
            data_df.set_value(counter,'Title',main_credits[int(id)]['cast'][x]['name'])
        counter= counter + 1
            
    for x in range(0,crew_credits):
        data_df.set_value(counter,"Name",main_stars[int(id)]['name'])
        data_df.set_value(counter,'Job',main_credits[int(id)]['crew'][x]['job'])
        data_df.set_value(counter,'Media',main_credits[int(id)]['crew'][x]['media_type'])
        data_df.set_value(counter,'Genre',main_credits[int(id)]['cast'][x]['genre_ids'])
        if main_credits[int(id)]['crew'][x]['media_type']=="movie":
            data_df.set_value(counter,'Date',main_credits[int(id)]['crew'][x]['release_date'])
            data_df.set_value(counter,'Title',main_credits[int(id)]['crew'][x]['title'])
            
        else:
            data_df.set_value(counter,'Date',main_credits[int(id)]['crew'][x]['first_air_date'])
            data_df.set_value(counter,'Title',main_credits[int(id)]['crew'][x]['name'])
        counter= counter + 1
data_df = data_df.reset_index(drop=True)            
data_df
# Out:
#                 Name       Job  Media        Date  \
# 0    William Shatner     Actor  movie  1979-12-06
# 1    William Shatner     Actor  movie  1982-06-03
# 2    William Shatner     Actor  movie  1984-05-31
# 3    William Shatner     Actor  movie  1986-11-25
# 4    William Shatner     Actor  movie  1989-06-09
# 5    William Shatner     Actor  movie  1991-12-05
# 6    William Shatner     Actor  movie  1994-11-17
# 7    William Shatner     Actor  movie  1961-12-01
# 8    William Shatner     Actor  movie  2000-12-14
# 9    William Shatner     Actor  movie  1991-07-19
# 10   William Shatner     Actor  movie  2005-03-11
# 11   William Shatner     Actor  movie  1982-12-10
# 12   William Shatner     Actor  movie  2002-04-22
# 13   William Shatner     Actor  movie  1999-01-01
# 14   William Shatner     Actor  movie  1977-08-24
# 15   William Shatner     Actor  movie  2002-03-14
# 16   William Shatner     Actor  movie  1995-09-29
# 17   William Shatner     Actor  movie  2012-12-02
# 18   William Shatner     Actor  movie  2006-04-22
# 19   William Shatner     Actor  movie  2001-11-06
# 20   William Shatner     Actor  movie  1993-02-04
# 21   William Shatner     Actor  movie  2009-04-12
# 22   William Shatner     Actor  movie  2006-03-06
# 23   William Shatner     Actor  movie  2009-02-06
# 24   William Shatner     Actor  movie  1998-06-04
# 25   William Shatner     Actor  movie  2008-12-11
# 26   William Shatner     Actor  movie  2001-04-17
# 27   William Shatner     Actor  movie  1973-02-13
# 28   William Shatner     Actor  movie  1976-03-17
# 29   William Shatner     Actor  movie  1974-10-01
# ..               ...       ...    ...         ...
# 804    Majel Barrett     Actor     tv  2004-10-08
# 805    Majel Barrett     Actor     tv  1966-09-08
# 806    Majel Barrett     Actor     tv  1966-09-08
# 807    Majel Barrett     Actor     tv  1966-09-08
# 808    Majel Barrett     Actor     tv  1966-09-08
# 809    Majel Barrett     Actor     tv  1993-01-03
# 810    Majel Barrett  Producer     tv  2000-10-02
# 811    Majel Barrett  Producer     tv  1997-10-06
# 812   Bill Blackburn     Actor  movie  1960-10-06
# 813   Bill Blackburn     Actor  movie  1967-04-11
# 814   Bill Blackburn     Actor     tv  1966-09-08
# 815   Bill Blackburn     Actor     tv  1966-09-08
# 816   Bill Blackburn     Actor     tv  1966-09-08
# 817   Bill Blackburn     Actor     tv  1966-09-08
# 818   Bill Blackburn     Actor     tv  1966-09-08
# 819   Bill Blackburn     Actor     tv  1966-09-08
# 820   Bill Blackburn     Actor     tv  1966-09-08
# 821   Bill Blackburn     Actor     tv  1966-09-08
# 822   Bill Blackburn     Actor     tv  1966-09-08
# 823   Bill Blackburn     Actor     tv  1966-09-08
# 824   Bill Blackburn  Director  movie  1991-01-01
# 825   Frank da Vinci     Actor     tv  1966-09-08
# 826   Frank da Vinci     Actor     tv  1966-09-08
# 827   Frank da Vinci     Actor     tv  1966-09-08
# 828   Frank da Vinci     Actor     tv  1966-09-08
# 829   Frank da Vinci     Actor     tv  1966-09-08
# 830   Frank da Vinci     Actor     tv  1966-09-08
# 831   Frank da Vinci     Actor     tv  1966-09-08
# 832   Frank da Vinci     Actor     tv  1966-09-08
# 833   Frank da Vinci     Actor     tv  1966-09-08
#
#                              Genre  \
# 0                  [12, 9648, 878]
# 1                [28, 12, 878, 53]
# 2                [28, 12, 878, 53]
# 3                        [12, 878]
# 4                [28, 12, 878, 53]
# 5                [28, 12, 878, 53]
# 6                [28, 12, 878, 53]
# 7                         [18, 36]
# 8                     [28, 35, 80]
# 9         [12, 35, 14, 878, 10751]
# 10                        [28, 35]
# 11                            [35]
# 12                        [27, 53]
# 13                        [99, 36]
# 14                       [27, 878]
# 15                        [28, 35]
# 16                            [99]
# 17                         [10751]
# 18                 [16, 35, 10751]
# 19                            [99]
# 20                    [28, 35, 80]
# 21                            [99]
# 22                     [16, 10751]
# 23                        [12, 35]
# 24                     [35, 10749]
# 25                     [16, 10751]
# 26                        [28, 53]
# 27                     [27, 10770]
# 28                            [99]
# 29                  [27, 9648, 53]
# ..                             ...
# 804                    [18, 10759]
# 805                    [18, 10765]
# 806                    [18, 10765]
# 807                    [18, 10765]
# 808                    [18, 10765]
# 809             [18, 10759, 10765]
# 810                [12, 9648, 878]
# 811  [28, 12, 18, 27, 878, 53, 37]
# 812                   [28, 18, 36]
# 813                           [35]
# 814                    [18, 10765]
# 815                    [18, 10765]
# 816                    [18, 10765]
# 817                    [18, 10765]
# 818                    [18, 10765]
# 819                    [18, 10765]
# 820                    [18, 10765]
# 821                    [18, 10765]
# 822                    [18, 10765]
# 823                    [18, 10765]
# 824                   [28, 18, 36]
# 825                    [18, 10765]
# 826                    [18, 10765]
# 827                    [18, 10765]
# 828                    [18, 10765]
# 829                    [18, 10765]
# 830                    [18, 10765]
# 831                    [18, 10765]
# 832                    [18, 10765]
# 833                    [18, 10765]
#
#                                                  Title
# 0                        Star Trek: The Motion Picture
# 1                      Star Trek II: The Wrath of Khan
# 2                  Star Trek III: The Search for Spock
# 3                        Star Trek IV: The Voyage Home
# 4                      Star Trek V: The Final Frontier
# 5               Star Trek VI: The Undiscovered Country
# 6                               Star Trek: Generations
# 7                                Judgment at Nuremberg
# 8                                    Miss Congeniality
# 9                           Bill & Ted's Bogus Journey
# 10             Miss Congeniality 2: Armed and Fabulous
# 11                             Airplane II: The Sequel
# 12                American Psycho 2: All American Girl
# 13                                      Nukes in Space
# 14                              Kingdom of the Spiders
# 15                                            Showtime
# 16           Trinity And Beyond: The Atomic Bomb Movie
# 17              Quantum Quest: A Cassini Space Odyssey
# 18                                      Over the Hedge
# 19   Mind Meld: Secrets Behind the Voyage of a Life...
# 20                  National Lampoon's Loaded Weapon 1
# 21                     Star Trek: The Captain's Summit
# 22                                            The Wild
# 23                                             Fanboys
# 24                                     Free Enterprise
# 25                             Gotta Catch Santa Claus
# 26                                         Falcon Down
# 27                           The Horror at 37,000 Feet
# 28                               Mysteries of the Gods
# 29                                             Impulse
# ..                                                 ...
# 804                                Star Trek: Phase II
# 805                                          Star Trek
# 806                                          Star Trek
# 807                                          Star Trek
# 808                                          Star Trek
# 809                         Star Trek: Deep Space Nine
# 810                                          Andromeda
# 811                              Earth: Final Conflict
# 812                                          Spartacus
# 813                                      The Cool Ones
# 814                                          Star Trek
# 815                                          Star Trek
# 816                                          Star Trek
# 817                                          Star Trek
# 818                                          Star Trek
# 819                                          Star Trek
# 820                                          Star Trek
# 821                                          Star Trek
# 822                                          Star Trek
# 823                                          Star Trek
# 824                                 Challenge the Wind
# 825                                          Star Trek
# 826                                          Star Trek
# 827                                          Star Trek
# 828                                          Star Trek
# 829                                          Star Trek
# 830                                          Star Trek
# 831                                          Star Trek
# 832                                          Star Trek
# 833                                          Star Trek
#
# [834 rows x 6 columns]

# %%
#read the genre csv file and load the DataFrame
genres="genre_list.csv"
genre_dics=pd.read_csv(genres,encoding="iso-8859-1")

#genre_dics

# %%
activity=data_df.groupby(['Name', 'Job', 'Media']).size().reset_index(name="count")
activity.head()
# Out:
#               Name       Job  Media  count
# 0   Bill Blackburn     Actor  movie      2
# 1   Bill Blackburn     Actor     tv     10
# 2   Bill Blackburn  Director  movie      1
# 3  DeForest Kelley     Actor  movie     33
# 4  DeForest Kelley     Actor     tv     38

# %%
test=activity.pivot_table( index= "Name", columns = "Job", values = "count")
test.fillna(0)
test
# Out:
# Job               Actor  Characters  Creator  Director  Executive Producer  \
# Name
# Bill Blackburn      6.0         NaN      NaN       1.0                 NaN
# DeForest Kelley    35.5         NaN      NaN       NaN                 NaN
# Frank da Vinci      9.0         NaN      NaN       NaN                 NaN
# George Takei       67.0         NaN      NaN       NaN                 NaN
# James Doohan       27.5         NaN      NaN       NaN                 NaN
# Leonard Nimoy      65.5         NaN      NaN       6.0                 NaN
# Majel Barrett      24.5         NaN      NaN       NaN                 NaN
# Nichelle Nichols   22.0         NaN      NaN       NaN                 NaN
# Walter Koenig      26.5         NaN      NaN       NaN                 NaN
# William Shatner   116.5         1.0      1.0       4.5                 3.0
#
# Job               Novel  Producer  Writer
# Name
# Bill Blackburn      NaN       NaN     NaN
# DeForest Kelley     NaN       NaN     NaN
# Frank da Vinci      NaN       NaN     NaN
# George Takei        NaN       NaN     NaN
# James Doohan        NaN       NaN     NaN
# Leonard Nimoy       NaN       NaN     NaN
# Majel Barrett       NaN       2.0     NaN
# Nichelle Nichols    NaN       NaN     NaN
# Walter Koenig       NaN       1.0     2.5
# William Shatner     2.0       2.0     2.0

# %%
test["Characters"]=test['Characters'].fillna(0)
test["Creator"]=test['Creator'].fillna(0)
test["Director"]=test['Director'].fillna(0)
test["Executive Producer"]=test['Executive Producer'].fillna(0)
test["Novel"]=test['Novel'].fillna(0)
test["Producer"]=test['Producer'].fillna(0)
test["Writer"]=test['Writer'].fillna(0)
test
# Out:
# Job               Actor  Characters  Creator  Director  Executive Producer  \
# Name
# Bill Blackburn      6.0         0.0      0.0       1.0                 0.0
# DeForest Kelley    35.5         0.0      0.0       0.0                 0.0
# Frank da Vinci      9.0         0.0      0.0       0.0                 0.0
# George Takei       67.0         0.0      0.0       0.0                 0.0
# James Doohan       27.5         0.0      0.0       0.0                 0.0
# Leonard Nimoy      65.5         0.0      0.0       6.0                 0.0
# Majel Barrett      24.5         0.0      0.0       0.0                 0.0
# Nichelle Nichols   22.0         0.0      0.0       0.0                 0.0
# Walter Koenig      26.5         0.0      0.0       0.0                 0.0
# William Shatner   116.5         1.0      1.0       4.5                 3.0
#
# Job               Novel  Producer  Writer
# Name
# Bill Blackburn      0.0       0.0     0.0
# DeForest Kelley     0.0       0.0     0.0
# Frank da Vinci      0.0       0.0     0.0
# George Takei        0.0       0.0     0.0
# James Doohan        0.0       0.0     0.0
# Leonard Nimoy       0.0       0.0     0.0
# Majel Barrett       0.0       2.0     0.0
# Nichelle Nichols    0.0       0.0     0.0
# Walter Koenig       0.0       1.0     2.5
# William Shatner     2.0       2.0     2.0

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style
style.use('ggplot')

# %%
# create the bar chart of activity
acting_gigs = {}

fig, ax = plt.subplots()


x_axis = np.arange(0, len(test) )
tick_locations = []
for x in x_axis:
    tick_locations.append(x + 0.4)
plt.xlim(-0.25, len(test))
plt.ylim(min(test['Actor']) - 1, max(test['Actor']) + 5)
plt.title(" Acting jobs for original cast of Star Trek")
plt.ylabel("Number of Jobs")

plt.xticks(tick_locations, test.index, rotation= "vertical")
bar_chart=plt.bar(x_axis, test['Actor'], color = '#F5173C', alpha=0.75, align="edge")

   

plt.savefig("Acting_Jobs_Main_Cast.png")
plt.show()

# %%
# create the bar chart of activity
acting_gigs = {}

fig, ax = plt.subplots()


x_axis = np.arange(0, len(test) )
tick_locations = []
for x in x_axis:
    tick_locations.append(x + 0.4)
plt.xlim(-0.25, len(test))
plt.ylim(min(test['Director']) - 0, max(test['Director']) + 1)
plt.title(" Directing & Producing jobs for original cast of Star Trek")
plt.ylabel("Number of Jobs")

plt.xticks(tick_locations, test.index, rotation= "vertical")
bar_chart=plt.bar(x_axis, (test['Director'] + test['Producer']), color = '#F5173C', alpha=0.75, align="edge")

   

plt.savefig("Dircting_Producing_jobs.png")
plt.show()

# %%
genre_test=data_df['Genre']
#genre_test
import collections
y=[]
for m in range(0,len(genre_test)):
    for n in range(0,len(genre_test[m])):
        y.append(genre_test[m][n])
w=collections.Counter(y).most_common()

# %%
genre_dics['Count']=0
for a in range(0,len(genre_dics)):
    for b in range(0,len(w)):
        if genre_dics['id'][a]==w[b][0]:
            genre_dics['Count'][a]=w[b][1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
genre_dics['Percent']=genre_dics['Count']/genre_dics['Count'].sum()
genre_dics.sort_values('Count')
genre_dics
# Out:
#        id                name  Count   Percent
# 0   10759  Action & Adventure     64  0.041531
# 1      16           Animation     64  0.041531
# 2      35              Comedy    159  0.103180
# 3      80               Crime     38  0.024659
# 4      99         Documentary    118  0.076574
# 5      18               Drama    294  0.190785
# 6   10751              Family     46  0.029851
# 7   10762                Kids      0  0.000000
# 8    9648             Mystery     53  0.034393
# 9   10763                News      8  0.005191
# 10  10764             Reality      4  0.002596
# 11  10765    Sci-Fi & Fantasy     95  0.061648
# 12  10766                Soap      0  0.000000
# 13  10767                Talk     10  0.006489
# 14  10768      War & Politics      6  0.003894
# 15     37             Western     53  0.034393
# 16     28              Action     98  0.063595
# 17     12           Adventure    104  0.067489
# 18     14             Fantasy     13  0.008436
# 19     36             History     16  0.010383
# 20     27              Horror     30  0.019468
# 21  10402               Music      9  0.005840
# 22  10749             Romance     15  0.009734
# 23    878     Science Fiction    131  0.085010
# 24  10770            TV Movie     32  0.020766
# 25     53            Thriller     68  0.044127
# 26  10752                 War     13  0.008436

# %%
# Set x axis and tick locations
x_axis = np.arange(len(genre_dics))
tick_locations = [value+0.4 for value in x_axis]

# Create a list indicating where to write x labels and set figure size to adjust for space
#plt.figure(figsize=(10,3))
plt.bar(x_axis, genre_dics["Count"], color = '#F5173C', alpha=0.5, align="edge")
plt.xticks(tick_locations, genre_dics["name"], rotation="vertical")

# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(genre_dics["Count"])+10)

# Set a Title and labels
plt.title("Genre of Work by Main Cast")
plt.xlabel("Genre")
plt.ylabel("Number of Jobs")
#save our graph and show the grap
plt.tight_layout()
plt.savefig("Main_Cast_Genre_count.png")
plt.show()
