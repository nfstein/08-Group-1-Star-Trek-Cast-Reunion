# %%
import json
import star_trek_tos_data as TOS
import pandas as pd

# %%
pd.DataFrame(TOS.guest_movies).index
# Out:
# Index(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'count',
#        'credits', 'genres', 'guest_ids', 'guest_names', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'status_code', 'status_message',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
TOS.guest_movies[52867]
# Out:
# {'adult': False,
#  'backdrop_path': '/y45J60QUBK9JWebK52WAlhQjo4B.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'count': 2,
#  'credits': {'cast': [{'cast_id': 1,
#     'character': 'Alan "Mollymauk" Musgrave',
#     'credit_id': '52fe4847c3a36847f815f7a1',
#     'gender': 2,
#     'id': 7505,
#     'name': 'Roddy McDowall',
#     'order': 0,
#     'profile_path': '/e0OZn5SUXHghdmAgJbF3uLHD5gf.jpg'},
#    {'cast_id': 5,
#     'character': 'Barbara Ann Green',
#     'credit_id': '52fe4847c3a36847f815f7b7',
#     'gender': 1,
#     'id': 4514,
#     'name': 'Tuesday Weld',
#     'order': 1,
#     'profile_path': '/wLVlljfTvppkfdQz9fNDizNpSuK.jpg'},
#    {'cast_id': 6,
#     'character': 'Marie Greene',
#     'credit_id': '52fe4847c3a36847f815f7bb',
#     'gender': 1,
#     'id': 83442,
#     'name': 'Lola Albright',
#     'order': 2,
#     'profile_path': '/gi3cmzOXHNLrNRl1Ina4Yl2FwKZ.jpg'},
#    {'cast_id': 7,
#     'character': 'Bob Bernard',
# ...

# %%
TOS.guest_stars[291]
# Out:
# {'adult': False,
#  'also_known_as': ['Frank J. Gorshin', 'Frank John Gorshin Jr.'],
#  'biography': 'Frank John Gorshin, Jr. (April 5, 1933 – May 17, 2005) was an American actor and comedian. He was perhaps best known as an impressionist, with many guest appearances on The Ed Sullivan Show and The Tonight Show (with host Steve Allen). His most famous acting role was as The Riddler in the Batman live action television series. Description above from the Wikipedia article Frank Gorshin, licensed under CC-BY-SA, full list of contributors on Wikipedia.',
#  'birthday': '1933-04-05',
#  'credits': {'cast': [{'adult': False,
#     'backdrop_path': '/6KXbhaxkgExC5EdDqAzRinhmoZ8.jpg',
#     'character': 'Dr. Fletcher',
#     'credit_id': '52fe4212c3a36847f8001b49',
#     'genre_ids': [9648, 878, 53],
#     'id': 63,
#     'original_language': 'en',
#     'original_title': 'Twelve Monkeys',
# ...

# %%
df = pd.DataFrame(TOS.guest_stars).T
df
#df[df['vote_count']>25].set_index('original_title').sort_values('count', ascending = False)[['count', 'guest_names', 'vote_average']]
# Out:
#          adult                                  also_known_as  \
# 246      False                                             []
# 291      False     [Frank J. Gorshin, Frank John Gorshin Jr.]
# 1209     False                                             []
# 1436     False                                             []
# 1745     False                                             []
# 1759     False                                             []
# 1793     False                           [ Ricardo Montalbán]
# 1820     False                                             []
# 1947     False                                             []
# 2021     False                                             []
# 2652     False                                             []
# 2782     False  [Ian Wolf, Ian Mac Wolfe, Ian Wulf, Ien Wulf]
# 3339     False                                  [Elisha Cook]
# 4076     False                                             []
# ...

# %%
guest_movie_ids = [id_num for id_num in TOS.guest_movies]
guest_star_id_to_name = {id_num: TOS.guest_stars[id_num]['name'] for id_num in TOS.guest_stars}
guest_star_name_to_id = {TOS.guest_stars[id_num]['name'] : id_num for id_num in TOS.guest_stars}

# %%
main_cast_star_ids = [id_num for id_num in TOS.main_cast_stars]
main_cast_movie_ids = [id_num for id_num in TOS.main_cast_movies]
main_cast_star_id_to_name = {id_num: TOS.main_cast_stars[id_num]['name'] for id_num in TOS.main_cast_stars}
main_cast_star_name_to_id = {TOS.main_cast_stars[id_num]['name'] : id_num for id_num in TOS.main_cast_stars}
