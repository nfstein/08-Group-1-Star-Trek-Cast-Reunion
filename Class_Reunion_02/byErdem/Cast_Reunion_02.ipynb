# %%
import json
import star_trek_tos_data as TOS
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dic = {}

for movie_id in TOS.guest_movies:
    movie_dat = TOS.guest_movies[movie_id]
    
    try:
        movie_dat['production_companies']
        
        for movie_co in movie_dat['production_companies']:
            print(movie_co['name'])
        
            if movie_co['name'] not in dic:
                dic[movie_co['name']] = 0
            dic[movie_co['name']] += len(movie_dat['guest_ids'])
    except KeyError:
        print('Error')
# Out:
# Universal International Pictures (UI)
# Columbia Pictures Corporation
# Orbit Productions
# Columbia Pictures
# Katzman Corporation
# Columbia Pictures Corporation
# Ross Hunter Productions Inc.
# Carrollton Inc.
# Columbia Pictures
# George Axelrod Productions
# Sunset Productions
# Warner Bros.
# United Artists
# Mirisch Corporation, The
# United Artists
# jackson-weston productions
# Columbia Pictures
# Ladd Enterprises
# Metro-Goldwyn-Mayer (MGM)
# Metro-Goldwyn-Mayer (MGM)
# United Pictures
# Metro-Goldwyn-Mayer (MGM)
# Gramercy Pictures
# RKO Radio Pictures
# Monogram Pictures
# Argosy Pictures
# Metro-Goldwyn-Mayer (MGM)
# Metro-Goldwyn-Mayer (MGM)
# Bryna Productions
# Universal International Pictures (UI)
# Graffiti Productions
# Security Pictures
# Theodora Productions
# Twentieth Century Fox Film Corporation
# MCL Films S.A.
# Walwa Films S.A.
# Metro-Goldwyn-Mayer (MGM)
# Metro-Goldwyn-Mayer (MGM)
# RKO Radio Pictures
# Mark Hellinger Productions
# ...

# %%
dic['Walter Wanger Productions']
# Out:
# 5

# %%
# for values in dic.values():
#     if values > 30:
#         print(values)

# %%
dic
# Out:
# {'Universal International Pictures (UI)': 114,
#  'Columbia Pictures Corporation': 157,
#  'Orbit Productions': 3,
#  'Columbia Pictures': 54,
#  'Katzman Corporation': 1,
#  'Ross Hunter Productions Inc.': 4,
#  'Carrollton Inc.': 2,
#  'George Axelrod Productions': 2,
#  'Sunset Productions': 2,
#  'Warner Bros.': 273,
#  'United Artists': 80,
#  'Mirisch Corporation, The': 5,
#  'jackson-weston productions': 1,
#  'Ladd Enterprises': 4,
#  'Metro-Goldwyn-Mayer (MGM)': 307,
#  'United Pictures': 7,
#  'Gramercy Pictures': 2,
#  'RKO Radio Pictures': 85,
#  'Monogram Pictures': 32,
#  'Argosy Pictures': 3,
#  'Bryna Productions': 9,
#  'Graffiti Productions': 1,
#  'Security Pictures': 8,
#  'Theodora Productions': 2,
#  'Twentieth Century Fox Film Corporation': 247,
#  'MCL Films S.A.': 1,
#  'Walwa Films S.A.': 1,
#  'Mark Hellinger Productions': 3,
#  'United States Pictures': 5,
#  'Fryman Enterprises': 3,
#  'Eagle-Lion Films': 5,
#  'Charles Martin Productions': 2,
# ...

# %%
df = pd.DataFrame()
df['Movie Company Name'] = dic.keys()
df['Number of Actor (Star Trak)'] = dic.values()
df = df.sort_values('Number of Actor (Star Trak)', ascending = False)
df.head(50)
# Out:
#                           Movie Company Name  Number of Actor (Star Trak)
# 14                 Metro-Goldwyn-Mayer (MGM)                          307
# 9                               Warner Bros.                          273
# 24    Twentieth Century Fox Film Corporation                          247
# 35                        Paramount Pictures                          210
# 81                        Universal Pictures                          182
# 1              Columbia Pictures Corporation                          157
# 0      Universal International Pictures (UI)                          114
# 17                        RKO Radio Pictures                           85
# 10                            United Artists                           80
# 3                          Columbia Pictures                           54
# 33     American International Pictures (AIP)                           51
# 283                        Republic Pictures                           48
# ...

# %%
clean_df = df.loc[df["Number of Actor (Star Trak)"] > 50]
clean_df
# Out:
#                         Movie Company Name  Number of Actor (Star Trak)
# 14               Metro-Goldwyn-Mayer (MGM)                          307
# 9                             Warner Bros.                          273
# 24  Twentieth Century Fox Film Corporation                          247
# 35                      Paramount Pictures                          210
# 81                      Universal Pictures                          182
# 1            Columbia Pictures Corporation                          157
# 0    Universal International Pictures (UI)                          114
# 17                      RKO Radio Pictures                           85
# 10                          United Artists                           80
# 3                        Columbia Pictures                           54
# 33   American International Pictures (AIP)                           51

# %%
for star in TOS.guest_stars:
    print(star)
# Out:
# 83913
# 168061
# 82510
# 14508
# 1213153
# 101742
# 39770
# 1214921
# 153336
# 90520
# 164771
# 1214891
# 30551
# 1214907
# 78692
# 1775091
# 1214881
# 1759
# 15621
# 1214880
# 1214877
# 15620
# 121759
# 1315468
# 1555684
# 135066
# 1745
# 1214885
# 15626
# 9805
# 1214884
# 1214883
# 127601
# 15628
# 8496
# 246
# 15635
# 1214878
# 1766901
# 1214888
# 1769423
# 12424
# 1214887
# 15645
# 15644
# 122004
# 1461992
# 1402879
# 9600
# 15650
# 119245
# 1212973
# 1776386
# 8490
# 8747
# 6451
# 15655
# 13869
# 1729741
# 14732
# 15659
# 161673
# 157282
# 1776894
# 1556119
# 1212769
# 15949
# 50974
# 15661
# 27126
# 1214900
# 936121
# 161340
# 161255
# 15676
# 1768121
# 129676
# 153675
# 1820
# 1213151
# 1769185
# 161663
# 1214896
# 196562
# 12295
# 1611570
# 1769186
# 1468833
# 15693
# 15692
# 1720860
# 178296
# 15746
# 1214902
# 15699
# 1768125
# 139933
# 1497387
# 151679
# 153501
# 1214565
# 84325
# 15707
# 1769187
# 15714
# 88451
# 10161
# 3339
# 166047
# 15719
# 1472601
# 19107
# 4076
# ...

# %%
url_ext = TOS.guest_stars[1759]['credits']['cast'][0]['backdrop_path']
base_url = 'https://image.tmdb.org/t/p/w500/'
url = base_url + url_ext
print(url)
# Out:
# https://image.tmdb.org/t/p/w500//w9iSKX1GSlaPPASW7jSFkFkkDnz.jpg

# %%
pd.DataFrame(TOS.guest_movies).T.set_index('original_title').sort_values('count', ascending = False)[['count', 'guest_ids', 'guest_names']]
# Out:
#                                               count  \
# original_title
# Spartacus                                         6
# The Greatest Story Ever Told                      6
# Emperor of the North Pole                         5
# Brute Corps                                       5
# Star Trek: Of Gods And Men                        5
# Batman                                            5
# Julius Caesar                                     5
# The Cage                                          5
# To Kill a Mockingbird                             5
# Scorpio                                           5
# True Grit                                         5
# Soylent Green                                     4
# 40 Pounds of Trouble                              4
# The High and the Mighty                           4
# Cry Tough                                         4
# One Man's Way                                     4
# Hitler                                            4
# ...

# %%
guest_star_ids = [id_num for id_num in TOS.guest_stars]
guest_movie_ids = [id_num for id_num in TOS.guest_movies]
guest_star_id_to_name = {id_num: TOS.guest_stars[id_num]['name'] for id_num in TOS.guest_stars}

# %%
main_cast_star_ids = [id_num for id_num in TOS.main_cast_stars]
main_cast_movie_ids = [id_num for id_num in TOS.main_cast_movies]
main_cast_star_id_to_name = {id_num: TOS.main_cast_stars[id_num]['name'] for id_num in TOS.main_cast_stars}

# %%
data = pd.DataFrame(TOS.guest_movies).T
data
# Out:
#         adult                     backdrop_path  \
# 62      False  /pckdZ29bHj11hBsV3SbVVfmCB6C.jpg
# 63      False  /6KXbhaxkgExC5EdDqAzRinhmoZ8.jpg
# 89      False  /m3bEQlir8IWpmFocQBXWM5fkHri.jpg
# 93      False  /8KOna8UEFGoTpTdxmabqS7z1q2c.jpg
# 114     False  /fztlIPN1EAO2kFVdJhKaXjAgjhH.jpg
# 132     False  /px4CI7soJx2OD654wY0GUPc7eyt.jpg
# 152     False  /w9iSKX1GSlaPPASW7jSFkFkkDnz.jpg
# 154     False  /gih4L6m9u1yB3PGwyJxB5wjzbqR.jpg
# 157     False  /vLsXNaLn7xIhwZdq3rUqQtoI8hd.jpg
# 164     False  /haHULz59jdG4OVmqHjZ01z7HEit.jpg
# 168     False  /2SmriSA5l4WE40KnZ8mA0GuqtEJ.jpg
# 174     False  /qzrOCLviAseY5WOmsgkNVIAHQea.jpg
# 184     False  /oT8RNPVSaZzEhimXcWihQxQPxKy.jpg
# 213     False  /AplR1QRswlXiM65GoifX8sDadME.jpg
# 220     False  /zsyeRF96SQO1eup5oYFlzyg3vMc.jpg
# 221     False  /aFrfCpEwyyAhIbooDANgWiFzV9R.jpg
# 239     False  /sdibVacEUaYcM41zmepM0J2xNqq.jpg
# 240     False  /gLbBRyS7MBrmVUNce91Hmx9vzqI.jpg
# ...

# %%
len(data)
# Out:
# 3937

# %%
data[['vote_average', 'title', 'guest_names']]
# Out:
#        vote_average                                   title  \
# 62              7.9                   2001: A Space Odyssey
# 63              7.4                          Twelve Monkeys
# 89              7.6      Indiana Jones and the Last Crusade
# 93              7.7                     Anatomy of a Murder
# 114               7                            Pretty Woman
# 132             7.8       The Rolling Stones: Gimme Shelter
# 152             6.2           Star Trek: The Motion Picture
# 154             7.3         Star Trek II: The Wrath of Khan
# 157             6.4     Star Trek III: The Search for Spock
# 164             7.6                  Breakfast at Tiffany's
# 168             6.9           Star Trek IV: The Voyage Home
# 174             6.7  Star Trek VI: The Undiscovered Country
# 184             7.3                            Jackie Brown
# 213             7.8                      North by Northwest
# 220             7.5                            East of Eden
# ...
