# %% [markdown]
# ## Import data and save it as json files

# %%
import pandas as pd
import os
import csv
import ast
from random import sample, randint
import json
import requests
from time import sleep
api_key = '1bb6cfd646261b1acda61748ca2bb5a7'

# %%
randint(0,97833)
# Out:
# 68713

# %%
num_movies = 97833
sample_ids = sample(range(1,num_movies),500)
#sample_movies format is id: {TMDbkeys: TMDbvalues, 'credits': creditsfromjson, 'movie': movie['original_title'], 'movie_id': movie, 'sample_names': [name, name, name] , 'sample_ids': [id_num, id_num, id_num], 'count': 3}
sample_movies = {}
sample_stars = {}
count = 0
movie_ids = []

api_key = '1bb6cfd646261b1acda61748ca2bb5a7'

# loops through each sample star [15620]):# 

if True:
    if True:
        for movie in sample_ids:
            #print(json.dumps(dat['cast, indent = 2, sort_keys= True))
                
            try:
                if movie not in sample_movies:
                    movie_url = f'https://api.themoviedb.org/3/movie/{movie}?api_key={api_key}&language=en-US'
                    movie_credits_url = f'https://api.themoviedb.org/3/movie/{movie}/credits?api_key={api_key}&language=en-US'
                    
                    #movie_count += 1
                    movie_dat = requests.get(movie_url).json()
                    sleep(.3)
                    movie_credits_dat = requests.get(movie_credits_url).json()
                    
                    sleep(.3)
                    #print(movie_count, end = '\t')
                    if len(movie_dat) > 5:
                        sample_movies[movie] = movie_dat
                        sample_movies[movie]['credits'] = movie_credits_dat
                    else:
                        print('\n error, adding value')
                        sample_ids.append(randint(0,num_movies))
                    '''
                    sample_movies[movie]['sample_names'] = []
                    sample_movies[movie]['sample_ids'] = []
                    sample_movies[movie]['count'] = 0
                    
                sample_movies[movie]['sample_names'].append(sample_stars_id_to_name[id_num])
                sample_movies[movie]['sample_ids'].append(id_num)
                sample_movies[movie]['count'] += 1 '''
                
            except KeyError:
                print('should not be able to enter this')
            count += 1
            print(count, '/', len(sample_ids), end = '\t')
        #Both Elizabeth Rogers and Peter Duryea errors fine they each now exist under two ids, one of which is correct the other popped above
        
            
    count += 1
    print(count, '/', len(sample_ids), end = '\t')
#print(sample_movies[movie])
#print(sample_stars)
with open('sample_movies.txt', 'w') as file:
    json.dump(sample_movies, file)
# Out:
# 1 / 500	2 / 500	3 / 500	4 / 500	5 / 500
#  error, adding value
# 6 / 501
#  error, adding value
# 7 / 502
#  error, adding value
# 8 / 503	9 / 503	10 / 503	11 / 503	12 / 503
#  error, adding value
# 13 / 504	14 / 504	15 / 504	16 / 504
#  error, adding value
# 17 / 505	18 / 505	19 / 505
#  error, adding value
# 20 / 506	21 / 506
#  error, adding value
# 22 / 507	23 / 507	24 / 507	25 / 507
#  error, adding value
# 26 / 508	27 / 508	28 / 508
#  error, adding value
# 29 / 509
#  error, adding value
# 30 / 510	31 / 510	32 / 510	33 / 510	34 / 510
#  error, adding value
# 35 / 511	36 / 511	37 / 511	38 / 511	39 / 511	40 / 511	41 / 511	42 / 511
#  error, adding value
# 43 / 512	44 / 512	45 / 512	46 / 512
#  error, adding value
# 47 / 513	48 / 513
#  error, adding value
# 49 / 514	50 / 514
#  error, adding value
# 51 / 515
#  error, adding value
# 52 / 516	53 / 516	54 / 516	55 / 516
#  error, adding value
# 56 / 517
#  error, adding value
# 57 / 518	58 / 518	59 / 518
#  error, adding value
# 60 / 519
#  error, adding value
# 61 / 520
#  error, adding value
# 62 / 521
#  error, adding value
# 63 / 522	64 / 522	65 / 522
#  error, adding value
# 66 / 523	67 / 523	68 / 523	69 / 523	70 / 523
#  error, adding value
# 71 / 524	72 / 524
#  error, adding value
# 73 / 525	74 / 525
#  error, adding value
# 75 / 526
#  error, adding value
# 76 / 527	77 / 527	78 / 527
#  error, adding value
# 79 / 528	80 / 528	81 / 528
#  error, adding value
# 82 / 529	83 / 529	84 / 529
#  error, adding value
# 85 / 530	86 / 530	87 / 530
#  error, adding value
# 88 / 531	89 / 531	90 / 531
#  error, adding value
# 91 / 532
#  error, adding value
# 92 / 533	93 / 533	94 / 533
#  error, adding value
# 95 / 534	96 / 534	97 / 534
#  error, adding value
# 98 / 535	99 / 535	100 / 535	101 / 535	102 / 535	103 / 535
#  error, adding value
# 104 / 536
#  error, adding value
# 105 / 537	106 / 537	107 / 537	108 / 537	109 / 537
#  error, adding value
# 110 / 538	111 / 538	112 / 538	113 / 538	114 / 538	115 / 538	116 / 538
#  error, adding value
# 117 / 539	118 / 539
#  error, adding value
# 119 / 540
#  error, adding value
# 120 / 541	121 / 541	122 / 541
#  error, adding value
# 123 / 542	124 / 542	125 / 542	126 / 542
#  error, adding value
# 127 / 543	128 / 543	129 / 543	130 / 543	131 / 543	132 / 543	133 / 543	134 / 543
#  error, adding value
# 135 / 544	136 / 544
#  error, adding value
# 137 / 545	138 / 545	139 / 545
#  error, adding value
# 140 / 546
#  error, adding value
# 141 / 547	142 / 547	143 / 547	144 / 547	145 / 547	146 / 547	147 / 547	148 / 547
#  error, adding value
# 149 / 548	150 / 548
#  error, adding value
# 151 / 549	152 / 549
#  error, adding value
# 153 / 550
#  error, adding value
# 154 / 551	155 / 551	156 / 551	157 / 551	158 / 551	159 / 551	160 / 551
#  error, adding value
# 161 / 552	162 / 552	163 / 552
#  error, adding value
# 164 / 553	165 / 553	166 / 553	167 / 553
#  error, adding value
# 168 / 554	169 / 554	170 / 554	171 / 554	172 / 554	173 / 554	174 / 554	175 / 554	176 / 554	177 / 554	178 / 554	179 / 554	180 / 554	181 / 554	182 / 554	183 / 554	184 / 554	185 / 554
#  error, adding value
# 186 / 555
#  error, adding value
# 187 / 556	188 / 556
#  error, adding value
# 189 / 557	190 / 557	191 / 557	192 / 557	193 / 557	194 / 557
#  error, adding value
# 195 / 558	196 / 558	197 / 558	198 / 558	199 / 558	200 / 558	201 / 558	202 / 558	203 / 558
#  error, adding value
# 204 / 559	205 / 559	206 / 559
#  error, adding value
# 207 / 560	208 / 560	209 / 560	210 / 560	211 / 560	212 / 560	213 / 560
#  error, adding value
# 214 / 561
#  error, adding value
# 215 / 562
#  error, adding value
# 216 / 563
#  error, adding value
# 217 / 564	218 / 564	219 / 564	220 / 564	221 / 564	222 / 564	223 / 564	224 / 564
#  error, adding value
# 225 / 565	226 / 565
#  error, adding value
# 227 / 566
#  error, adding value
# 228 / 567
#  error, adding value
# 229 / 568	230 / 568
#  error, adding value
# 231 / 569	232 / 569	233 / 569	234 / 569
#  error, adding value
# 235 / 570	236 / 570	237 / 570
#  error, adding value
# 238 / 571	239 / 571	240 / 571	241 / 571	242 / 571	243 / 571	244 / 571	245 / 571	246 / 571
#  error, adding value
# 247 / 572	248 / 572	249 / 572	250 / 572	251 / 572	252 / 572
#  error, adding value
# 253 / 573	254 / 573	255 / 573	256 / 573	257 / 573
#  error, adding value
# 258 / 574
#  error, adding value
# 259 / 575	260 / 575	261 / 575
#  error, adding value
# 262 / 576	263 / 576	264 / 576
#  error, adding value
# 265 / 577	266 / 577	267 / 577	268 / 577
#  error, adding value
# 269 / 578	270 / 578	271 / 578	272 / 578
#  error, adding value
# 273 / 579	274 / 579	275 / 579	276 / 579	277 / 579	278 / 579	279 / 579
#  error, adding value
# 280 / 580	281 / 580
#  error, adding value
# 282 / 581
#  error, adding value
# 283 / 582	284 / 582	285 / 582
#  error, adding value
# 286 / 583
#  error, adding value
# 287 / 584
#  error, adding value
# 288 / 585
#  error, adding value
# 289 / 586
#  error, adding value
# 290 / 587	291 / 587	292 / 587	293 / 587
#  error, adding value
# 294 / 588	295 / 588	296 / 588	297 / 588
#  error, adding value
# 298 / 589
#  error, adding value
# 299 / 590
#  error, adding value
# 300 / 591	301 / 591	302 / 591	303 / 591
#  error, adding value
# 304 / 592	305 / 592	306 / 592	307 / 592	308 / 592	309 / 592	310 / 592	311 / 592	312 / 592
#  error, adding value
# 313 / 593	314 / 593	315 / 593	316 / 593	317 / 593
#  error, adding value
# 318 / 594	319 / 594	320 / 594	321 / 594	322 / 594	323 / 594	324 / 594	325 / 594
#  error, adding value
# 326 / 595	327 / 595	328 / 595	329 / 595
#  error, adding value
# 330 / 596
#  error, adding value
# 331 / 597
#  error, adding value
# 332 / 598
#  error, adding value
# 333 / 599	334 / 599	335 / 599
#  error, adding value
# 336 / 600
#  error, adding value
# 337 / 601	338 / 601	339 / 601	340 / 601	341 / 601
#  error, adding value
# 342 / 602	343 / 602	344 / 602	345 / 602
#  error, adding value
# 346 / 603	347 / 603	348 / 603	349 / 603	350 / 603	351 / 603
#  error, adding value
# 352 / 604
#  error, adding value
# 353 / 605
#  error, adding value
# 354 / 606
#  error, adding value
# 355 / 607
#  error, adding value
# 356 / 608
#  error, adding value
# 357 / 609	358 / 609
#  error, adding value
# 359 / 610	360 / 610
#  error, adding value
# 361 / 611	362 / 611	363 / 611	364 / 611	365 / 611	366 / 611	367 / 611	368 / 611
#  error, adding value
# 369 / 612
#  error, adding value
# 370 / 613	371 / 613	372 / 613
#  error, adding value
# 373 / 614
#  error, adding value
# 374 / 615	375 / 615
#  error, adding value
# 376 / 616	377 / 616	378 / 616	379 / 616
#  error, adding value
# 380 / 617	381 / 617	382 / 617
#  error, adding value
# 383 / 618	384 / 618	385 / 618	386 / 618	387 / 618	388 / 618
#  error, adding value
# 389 / 619	390 / 619
#  error, adding value
# 391 / 620	392 / 620	393 / 620	394 / 620	395 / 620	396 / 620	397 / 620	398 / 620
#  error, adding value
# 399 / 621	400 / 621	401 / 621	402 / 621	403 / 621	404 / 621
#  error, adding value
# 405 / 622
#  error, adding value
# 406 / 623
#  error, adding value
# 407 / 624	408 / 624	409 / 624	410 / 624	411 / 624	412 / 624	413 / 624
#  error, adding value
# 414 / 625	415 / 625	416 / 625
#  error, adding value
# 417 / 626	418 / 626
#  error, adding value
# 419 / 627	420 / 627	421 / 627	422 / 627	423 / 627	424 / 627	425 / 627
#  error, adding value
# 426 / 628
#  error, adding value
# 427 / 629	428 / 629	429 / 629	430 / 629	431 / 629	432 / 629
#  error, adding value
# 433 / 630	434 / 630
#  error, adding value
# 435 / 631	436 / 631	437 / 631	438 / 631	439 / 631	440 / 631	441 / 631
#  error, adding value
# 442 / 632	443 / 632
#  error, adding value
# 444 / 633	445 / 633
#  error, adding value
# 446 / 634	447 / 634	448 / 634	449 / 634	450 / 634
#  error, adding value
# 451 / 635
#  error, adding value
# 452 / 636
#  error, adding value
# 453 / 637	454 / 637	455 / 637	456 / 637
#  error, adding value
# 457 / 638	458 / 638	459 / 638	460 / 638	461 / 638	462 / 638
#  error, adding value
# 463 / 639
#  error, adding value
# 464 / 640	465 / 640	466 / 640	467 / 640	468 / 640	469 / 640	470 / 640
#  error, adding value
# 471 / 641	472 / 641
#  error, adding value
# 473 / 642	474 / 642	475 / 642
#  error, adding value
# 476 / 643	477 / 643	478 / 643	479 / 643
#  error, adding value
# 480 / 644	481 / 644
#  error, adding value
# 482 / 645	483 / 645	484 / 645	485 / 645	486 / 645	487 / 645	488 / 645	489 / 645	490 / 645	491 / 645	492 / 645	493 / 645	494 / 645	495 / 645
#  error, adding value
# 496 / 646
#  error, adding value
# 497 / 647
#  error, adding value
# 498 / 648	499 / 648	500 / 648	501 / 648	502 / 648
#  error, adding value
# 503 / 649
#  error, adding value
# 504 / 650	505 / 650	506 / 650
#  error, adding value
# 507 / 651	508 / 651	509 / 651
#  error, adding value
# 510 / 652
#  error, adding value
# 511 / 653
#  error, adding value
# 512 / 654	513 / 654	514 / 654	515 / 654
#  error, adding value
# 516 / 655	517 / 655
#  error, adding value
# 518 / 656	519 / 656
#  error, adding value
# 520 / 657	521 / 657
#  error, adding value
# 522 / 658
#  error, adding value
# 523 / 659	524 / 659	525 / 659	526 / 659	527 / 659
#  error, adding value
# 528 / 660
#  error, adding value
# 529 / 661
#  error, adding value
# 530 / 662	531 / 662	532 / 662	533 / 662	534 / 662	535 / 662	536 / 662	537 / 662	538 / 662	539 / 662	540 / 662	541 / 662	542 / 662
#  error, adding value
# 543 / 663	544 / 663	545 / 663	546 / 663	547 / 663	548 / 663	549 / 663	550 / 663	551 / 663	552 / 663
#  error, adding value
# 553 / 664	554 / 664	555 / 664	556 / 664	557 / 664
#  error, adding value
# 558 / 665
#  error, adding value
# 559 / 666	560 / 666	561 / 666
#  error, adding value
# 562 / 667
#  error, adding value
# 563 / 668	564 / 668	565 / 668	566 / 668	567 / 668	568 / 668	569 / 668
#  error, adding value
# 570 / 669	571 / 669
#  error, adding value
# 572 / 670
#  error, adding value
# 573 / 671	574 / 671	575 / 671
#  error, adding value
# 576 / 672	577 / 672	578 / 672	579 / 672	580 / 672	581 / 672	582 / 672	583 / 672	584 / 672	585 / 672
#  error, adding value
# 586 / 673	587 / 673	588 / 673	589 / 673	590 / 673	591 / 673	592 / 673	593 / 673
#  error, adding value
# 594 / 674	595 / 674	596 / 674
#  error, adding value
# 597 / 675	598 / 675	599 / 675	600 / 675
#  error, adding value
# 601 / 676	602 / 676	603 / 676
#  error, adding value
# 604 / 677	605 / 677	606 / 677
#  error, adding value
# 607 / 678	608 / 678	609 / 678	610 / 678	611 / 678	612 / 678
#  error, adding value
# 613 / 679	614 / 679	615 / 679	616 / 679	617 / 679	618 / 679	619 / 679	620 / 679	621 / 679
#  error, adding value
# 622 / 680	623 / 680	624 / 680	625 / 680
#  error, adding value
# 626 / 681	627 / 681	628 / 681	629 / 681
#  error, adding value
# 630 / 682	631 / 682
#  error, adding value
# 632 / 683	633 / 683	634 / 683	635 / 683	636 / 683
#  error, adding value
# 637 / 684	638 / 684	639 / 684	640 / 684	641 / 684	642 / 684	643 / 684	644 / 684	645 / 684
#  error, adding value
# 646 / 685	647 / 685	648 / 685	649 / 685	650 / 685
#  error, adding value
# 651 / 686	652 / 686	653 / 686	654 / 686
#  error, adding value
# 655 / 687	656 / 687	657 / 687
#  error, adding value
# 658 / 688	659 / 688	660 / 688
#  error, adding value
# 661 / 689	662 / 689	663 / 689
#  error, adding value
# 664 / 690	665 / 690	666 / 690	667 / 690	668 / 690	669 / 690	670 / 690
#  error, adding value
# 671 / 691	672 / 691
#  error, adding value
# 673 / 692
#  error, adding value
# 674 / 693	675 / 693
#  error, adding value
# 676 / 694	677 / 694	678 / 694	679 / 694
#  error, adding value
# 680 / 695	681 / 695	682 / 695	683 / 695	684 / 695	685 / 695	686 / 695	687 / 695	688 / 695	689 / 695	690 / 695	691 / 695	692 / 695	693 / 695	694 / 695	695 / 695	696 / 695

# %%
#sample_movies format is {'movie': movie['original_title'], 'movie_id': movie['id'], 'sample_names': [name, name, name] , 'sample_ids': [id_num, id_num, id_num], 'count': 3}
num_stars = 149950
num_samples = 500
sample_ids = sample(range(1,num_stars),num_samples)
sample_stars = {}
count = 0
success_count = 0

api_key = '1bb6cfd646261b1acda61748ca2bb5a7'

# loops through each sample star #[1748]):# 
for index, id_num in enumerate(sample_ids):
    count += 1
    print(f'\n {count} / {len(sample_ids) -- {success_count} / {num_samples}}', end = '\t')
    try:
        url = f'https://api.themoviedb.org/3/person/{id_num}/movie_credits?api_key={api_key}&language=en-US'
        dat = requests.get(url).json()
        movie_count = 0
        #print(json.dumps(dat , indent = 2, sort_keys= True))
        dat['cast'][0] #kicks to except if doesn't exist or isnt an actor
        url = f'https://api.themoviedb.org/3/person/{id_num}?api_key={api_key}&language=en-US'
        dat2 = requests.get(url).json()
        sample_stars[id_num] = dat2
        sample_stars[id_num]['credits'] = dat
        success_count += 1
    except KeyError:
        print('\nerror doesnt exist, adding value')
        sample_ids.append(randint(1,num_stars))
    except IndexError:
        print('\nerror never an actor, adding value')
        sample_ids.append(randint(1,num_stars))
#print(sample_movies[movie['id']])
#print(sample_stars)
with open('sample_stars.txt', 'w') as file:
    json.dump(sample_stars, file)
# Out:
#  0 / 500
#  1 / 500
#  2 / 500
#  3 / 500
# error doesnt exist, adding value
#
#  3 / 501
# error never an actor, adding value
#
#  3 / 502
#  4 / 502
#  5 / 502
# error doesnt exist, adding value
#
#  5 / 503
#  6 / 503
#  7 / 503
#  8 / 503
# error never an actor, adding value
#
#  8 / 504
#  9 / 504
#  10 / 504
#  11 / 504
#  12 / 504
#  13 / 504
#  14 / 504
#  15 / 504
#  16 / 504
#  17 / 504
# error doesnt exist, adding value
#
#  17 / 505
#  18 / 505
#  19 / 505
# error never an actor, adding value
#
#  19 / 506
# error doesnt exist, adding value
#
#  19 / 507
# error never an actor, adding value
#
#  19 / 508
# error never an actor, adding value
#
#  19 / 509
# error never an actor, adding value
#
#  19 / 510
#  20 / 510
# error never an actor, adding value
#
#  20 / 511
# error never an actor, adding value
#
#  20 / 512
# error never an actor, adding value
#
#  20 / 513
#  21 / 513
#  22 / 513
#  23 / 513
#  24 / 513
# error never an actor, adding value
#
#  24 / 514
#  25 / 514
# error never an actor, adding value
#
#  25 / 515
#  26 / 515
#  27 / 515
#  28 / 515
# error never an actor, adding value
#
#  28 / 516
#  29 / 516
# error never an actor, adding value
#
#  29 / 517
# error never an actor, adding value
#
#  29 / 518
# error never an actor, adding value
#
#  29 / 519
#  30 / 519
# error never an actor, adding value
#
#  30 / 520
# error doesnt exist, adding value
#
#  30 / 521
# error never an actor, adding value
#
#  30 / 522
#  31 / 522
#  32 / 522
# error doesnt exist, adding value
#
#  32 / 523
# error doesnt exist, adding value
#
#  32 / 524
# error never an actor, adding value
#
#  32 / 525
#  33 / 525
# error doesnt exist, adding value
#
#  33 / 526
# error doesnt exist, adding value
#
#  33 / 527
#  34 / 527
# error doesnt exist, adding value
#
#  34 / 528
#  35 / 528
# error doesnt exist, adding value
#
#  35 / 529
# error doesnt exist, adding value
#
#  35 / 530
# error doesnt exist, adding value
#
#  35 / 531
# error doesnt exist, adding value
#
#  35 / 532
# error doesnt exist, adding value
#
#  35 / 533
#  36 / 533
# error never an actor, adding value
#
#  36 / 534
# error doesnt exist, adding value
#
#  36 / 535
#  37 / 535
#  38 / 535
# error doesnt exist, adding value
#
#  38 / 536
#  39 / 536
#  40 / 536
#  41 / 536
# error never an actor, adding value
#
#  41 / 537
# error never an actor, adding value
#
#  41 / 538
#  42 / 538
#  43 / 538
#  44 / 538
#  45 / 538
# error never an actor, adding value
#
#  45 / 539
#  46 / 539
#  47 / 539
#  48 / 539
# error never an actor, adding value
#
#  48 / 540
#  49 / 540
# error never an actor, adding value
#
#  49 / 541
#  50 / 541
# error never an actor, adding value
#
#  50 / 542
#  51 / 542
#  52 / 542
#  53 / 542
# error never an actor, adding value
#
#  53 / 543
#  54 / 543
# error doesnt exist, adding value
#
#  54 / 544
# error doesnt exist, adding value
#
#  54 / 545
#  55 / 545
# error never an actor, adding value
#
#  55 / 546
# error doesnt exist, adding value
#
#  55 / 547
#  56 / 547
#  57 / 547
# error doesnt exist, adding value
#
#  57 / 548
#  58 / 548
#  59 / 548
#  60 / 548
#  61 / 548
#  62 / 548
#  63 / 548
# error never an actor, adding value
#
#  63 / 549
# error doesnt exist, adding value
#
#  63 / 550
#  64 / 550
#  65 / 550
#  66 / 550
# error never an actor, adding value
#
#  66 / 551
#  67 / 551
# error doesnt exist, adding value
#
#  67 / 552
#  68 / 552
#  69 / 552
#  70 / 552
#  71 / 552
#  72 / 552
#  73 / 552
#  74 / 552
#  75 / 552
# error never an actor, adding value
#
#  75 / 553
#  76 / 553
# error never an actor, adding value
#
#  76 / 554
#  77 / 554
#  78 / 554
#  79 / 554
#  80 / 554
# error never an actor, adding value
#
#  80 / 555
#  81 / 555
#  82 / 555
# error doesnt exist, adding value
#
#  82 / 556
#  83 / 556
#  84 / 556
#  85 / 556
#  86 / 556
# error doesnt exist, adding value
#
#  86 / 557
#  87 / 557
#  88 / 557
# error never an actor, adding value
#
#  88 / 558
# error never an actor, adding value
#
#  88 / 559
#  89 / 559
#  90 / 559
#  91 / 559
# error never an actor, adding value
#
#  91 / 560
#  92 / 560
# error never an actor, adding value
#
#  92 / 561
#  93 / 561
# error never an actor, adding value
#
#  93 / 562
#  94 / 562
#  95 / 562
#  96 / 562
# error doesnt exist, adding value
#
#  96 / 563
# error doesnt exist, adding value
#
#  96 / 564
# error doesnt exist, adding value
#
#  96 / 565
#  97 / 565
# error never an actor, adding value
#
#  97 / 566
#  98 / 566
#  99 / 566
#  100 / 566
#  101 / 566
#  102 / 566
# error never an actor, adding value
#
#  102 / 567
# error never an actor, adding value
#
#  102 / 568
# error never an actor, adding value
#
#  102 / 569
# error doesnt exist, adding value
#
#  102 / 570
#  103 / 570
#  104 / 570
#  105 / 570
# error never an actor, adding value
#
#  105 / 571
# error never an actor, adding value
#
#  105 / 572
# error doesnt exist, adding value
#
#  105 / 573
#  106 / 573
# error never an actor, adding value
#
#  106 / 574
#  107 / 574
# error never an actor, adding value
#
#  107 / 575
# error never an actor, adding value
#
#  107 / 576
# error never an actor, adding value
#
#  107 / 577
# error never an actor, adding value
#
#  107 / 578
# error never an actor, adding value
#
#  107 / 579
#  108 / 579
# error never an actor, adding value
#
#  108 / 580
# error never an actor, adding value
#
#  108 / 581
#  109 / 581
# error doesnt exist, adding value
#
#  109 / 582
#  110 / 582
# error never an actor, adding value
#
#  110 / 583
# error doesnt exist, adding value
#
#  110 / 584
#  111 / 584
#  112 / 584
#  113 / 584
# error never an actor, adding value
#
#  113 / 585
#  114 / 585
# error doesnt exist, adding value
#
#  114 / 586
#  115 / 586
#  116 / 586
# error doesnt exist, adding value
#
#  116 / 587
# error doesnt exist, adding value
#
#  116 / 588
# error never an actor, adding value
#
#  116 / 589
# error never an actor, adding value
#
#  116 / 590
# error never an actor, adding value
#
#  116 / 591
#  117 / 591
#  118 / 591
# error never an actor, adding value
#
#  118 / 592
# error doesnt exist, adding value
#
#  118 / 593
#  119 / 593
# error never an actor, adding value
#
#  119 / 594
#  120 / 594
#  121 / 594
#  122 / 594
#  123 / 594
# error never an actor, adding value
#
#  123 / 595
#  124 / 595
#  125 / 595
#  126 / 595
#  127 / 595
#  128 / 595
# error never an actor, adding value
#
#  128 / 596
#  129 / 596
#  130 / 596
#  131 / 596
# error doesnt exist, adding value
#
#  131 / 597
# error never an actor, adding value
#
#  131 / 598
# error doesnt exist, adding value
#
#  131 / 599
#  132 / 599
# error never an actor, adding value
#
#  132 / 600
#  133 / 600
#  134 / 600
# error never an actor, adding value
#
#  134 / 601
# error never an actor, adding value
#
#  134 / 602
# error never an actor, adding value
#
#  134 / 603
#  135 / 603
# error doesnt exist, adding value
#
#  135 / 604
# error doesnt exist, adding value
#
#  135 / 605
#  136 / 605
#  137 / 605
#  138 / 605
#  139 / 605
#  140 / 605
#  141 / 605
# error never an actor, adding value
#
#  141 / 606
#  142 / 606
#  143 / 606
#  144 / 606
#  145 / 606
# error doesnt exist, adding value
#
#  145 / 607
# error never an actor, adding value
#
#  145 / 608
# error doesnt exist, adding value
#
#  145 / 609
# error never an actor, adding value
#
#  145 / 610
# error doesnt exist, adding value
#
#  145 / 611
#  146 / 611
#  147 / 611
# error never an actor, adding value
#
#  147 / 612
# error doesnt exist, adding value
#
#  147 / 613
#  148 / 613
# error doesnt exist, adding value
#
#  148 / 614
#  149 / 614
# error never an actor, adding value
#
#  149 / 615
# error never an actor, adding value
#
#  149 / 616
# error never an actor, adding value
#
#  149 / 617
# error never an actor, adding value
#
#  149 / 618
#  150 / 618
#  151 / 618
# error never an actor, adding value
#
#  151 / 619
# error never an actor, adding value
#
#  151 / 620
# error never an actor, adding value
#
#  151 / 621
# error doesnt exist, adding value
#
#  151 / 622
#  152 / 622
# error never an actor, adding value
#
#  152 / 623
#  153 / 623
# error doesnt exist, adding value
#
#  153 / 624
#  154 / 624
# error never an actor, adding value
#
#  154 / 625
# error doesnt exist, adding value
#
#  154 / 626
#  155 / 626
#  156 / 626
# error never an actor, adding value
#
#  156 / 627
#  157 / 627
# error never an actor, adding value
#
#  157 / 628
#  158 / 628
#  159 / 628
#  160 / 628
#  161 / 628
# error never an actor, adding value
#
#  161 / 629
# error doesnt exist, adding value
#
#  161 / 630
# error doesnt exist, adding value
#
#  161 / 631
#  162 / 631
# error never an actor, adding value
#
#  162 / 632
# error never an actor, adding value
#
#  162 / 633
#  163 / 633
#  164 / 633
#  165 / 633
#  166 / 633
#  167 / 633
# error doesnt exist, adding value
#
#  167 / 634
# error never an actor, adding value
#  167 / 635
#  168 / 635
#  169 / 635
#  170 / 635
#  171 / 635
#  172 / 635
# error never an actor, adding value
#
#  172 / 636
#  173 / 636
# error never an actor, adding value
#
#  173 / 637
#  174 / 637
# error doesnt exist, adding value
#
#  174 / 638
#  175 / 638
#  176 / 638
#  177 / 638
#  178 / 638
#  179 / 638
# error never an actor, adding value
#
#  179 / 639
#  180 / 639
#  181 / 639
#  182 / 639
# error never an actor, adding value
#
#  182 / 640
# error never an actor, adding value
#
#  182 / 641
# error doesnt exist, adding value
#
#  182 / 642
# error never an actor, adding value
#
#  182 / 643
# error never an actor, adding value
#
#  182 / 644
# error never an actor, adding value
#
#  182 / 645
#  183 / 645
#  184 / 645
# error never an actor, adding value
#
#  184 / 646
#  185 / 646
# error never an actor, adding value
#
#  185 / 647
#  186 / 647
#  187 / 647
#  188 / 647
#  189 / 647
# error doesnt exist, adding value
#
#  189 / 648
# error never an actor, adding value
#
#  189 / 649
# error doesnt exist, adding value
#
#  189 / 650
#  190 / 650
# error doesnt exist, adding value
#
#  190 / 651
#  191 / 651
#  192 / 651
#  193 / 651
#  194 / 651
# error never an actor, adding value
#
#  194 / 652
#  195 / 652
# error never an actor, adding value
#
#  195 / 653
# error never an actor, adding value
#
#  195 / 654
#  196 / 654
#  197 / 654
#  198 / 654
# error doesnt exist, adding value
#
#  198 / 655
# error never an actor, adding value
#
#  198 / 656
# error never an actor, adding value
#
#  198 / 657
#  199 / 657
#  200 / 657
#  201 / 657
#  202 / 657
# error never an actor, adding value
#
#  202 / 658
#  203 / 658
#  204 / 658
#  205 / 658
# error never an actor, adding value
#
#  205 / 659
# error never an actor, adding value
#
#  205 / 660
#  206 / 660
# error doesnt exist, adding value
#
#  206 / 661
#  207 / 661
# error never an actor, adding value
#
#  207 / 662
#  208 / 662
#  209 / 662
# error never an actor, adding value
#
#  209 / 663
#  210 / 663
#  211 / 663
#  212 / 663
#  213 / 663
# error never an actor, adding value
#
#  213 / 664
# error never an actor, adding value
#
#  213 / 665
# error doesnt exist, adding value
#
#  213 / 666
# error never an actor, adding value
#
#  213 / 667
#  214 / 667
#  215 / 667
# error never an actor, adding value
#
#  215 / 668
#  216 / 668
#  217 / 668
#  218 / 668
# error never an actor, adding value
#
#  218 / 669
# error doesnt exist, adding value
#
#  218 / 670
# error doesnt exist, adding value
#
#  218 / 671
# error never an actor, adding value
#
#  218 / 672
#  219 / 672
# error never an actor, adding value
#
#  219 / 673
#  220 / 673
#  221 / 673
#  222 / 673
# error never an actor, adding value
#
#  222 / 674
# error doesnt exist, adding value
#
#  222 / 675
#  223 / 675
#  224 / 675
#  225 / 675
#  226 / 675
#  227 / 675
# error doesnt exist, adding value
#
#  227 / 676
#  228 / 676
# error doesnt exist, adding value
#
#  228 / 677
#  229 / 677
# error never an actor, adding value
#
#  229 / 678
# error doesnt exist, adding value
#
#  229 / 679
# error doesnt exist, adding value
#
#  229 / 680
#  230 / 680
# error never an actor, adding value
#
#  230 / 681
#  231 / 681
# error doesnt exist, adding value
#
#  231 / 682
#  232 / 682
#  233 / 682
#  234 / 682
# error never an actor, adding value
#
#  234 / 683
#  235 / 683
# error never an actor, adding value
#
#  235 / 684
#  236 / 684
#  237 / 684
# error never an actor, adding value
#
#  237 / 685
# error doesnt exist, adding value
#
#  237 / 686
#  238 / 686
#  239 / 686
#  240 / 686
# error doesnt exist, adding value
#
#  240 / 687
#  241 / 687
#  242 / 687
#  243 / 687
# error doesnt exist, adding value
#
#  243 / 688
# error doesnt exist, adding value
#
#  243 / 689
# error doesnt exist, adding value
#
#  243 / 690
# error never an actor, adding value
#
#  243 / 691
# error never an actor, adding value
#
#  243 / 692
#  244 / 692
# error never an actor, adding value
#
#  244 / 693
# error doesnt exist, adding value
#
#  244 / 694
#  245 / 694
# error never an actor, adding value
#
#  245 / 695
# error never an actor, adding value
#
#  245 / 696
# error doesnt exist, adding value
#
#  245 / 697
#  246 / 697
# error doesnt exist, adding value
#
#  246 / 698
# error doesnt exist, adding value
#
#  246 / 699
#  247 / 699
# error never an actor, adding value
#
#  247 / 700
#  248 / 700
#  249 / 700
#  250 / 700
# error doesnt exist, adding value
#
#  250 / 701
#  251 / 701
# error never an actor, adding value
#
#  251 / 702
#  252 / 702
#  253 / 702
#  254 / 702
#  255 / 702
#  256 / 702
#  257 / 702
#  258 / 702
# error never an actor, adding value
#
#  258 / 703
# error never an actor, adding value
#
#  258 / 704
#  259 / 704
# error never an actor, adding value
#
#  259 / 705
#  260 / 705
# error never an actor, adding value
#
#  260 / 706
#  261 / 706
# error doesnt exist, adding value
#
#  261 / 707
#  262 / 707
# error never an actor, adding value
#
#  262 / 708
#  263 / 708
# error doesnt exist, adding value
#
#  263 / 709
# error doesnt exist, adding value
#
#  263 / 710
# error never an actor, adding value
#
#  263 / 711
#  264 / 711
#  265 / 711
# error never an actor, adding value
#
#  265 / 712
#  266 / 712
#  267 / 712
#  268 / 712
#  269 / 712
#  270 / 712
#  271 / 712
# error never an actor, adding value
#
#  271 / 713
# error never an actor, adding value
#
#  271 / 714
#  272 / 714
#  273 / 714
#  274 / 714
#  275 / 714
#  276 / 714
# error doesnt exist, adding value
#
#  276 / 715
# error never an actor, adding value
#
#  276 / 716
#  277 / 716
#  278 / 716
# error never an actor, adding value
#
#  278 / 717
#  279 / 717
# error never an actor, adding value
#
#  279 / 718
#  280 / 718
# error never an actor, adding value
#
#  280 / 719
# error doesnt exist, adding value
#
#  280 / 720
# error never an actor, adding value
#
#  280 / 721
# error doesnt exist, adding value
#
#  280 / 722
#  281 / 722
# error doesnt exist, adding value
#
#  281 / 723
# error never an actor, adding value
#
#  281 / 724
#  282 / 724
# error doesnt exist, adding value
#
#  282 / 725
# error never an actor, adding value
#
#  282 / 726
# error never an actor, adding value
#
#  282 / 727
# error doesnt exist, adding value
#
#  282 / 728
# error doesnt exist, adding value
#
#  282 / 729
# error doesnt exist, adding value
#
#  282 / 730
# error doesnt exist, adding value
#
#  282 / 731
# error doesnt exist, adding value
#
#  282 / 732
#  283 / 732
# error never an actor, adding value
#
#  283 / 733
#  284 / 733
#  285 / 733
# error doesnt exist, adding value
#
#  285 / 734
#  286 / 734
#  287 / 734
#  288 / 734
#  289 / 734
# error never an actor, adding value
#
#  289 / 735
# error doesnt exist, adding value
#
#  289 / 736
# error never an actor, adding value
#
#  289 / 737
# error never an actor, adding value
#
#  289 / 738
# error never an actor, adding value
#
#  289 / 739
# error never an actor, adding value
#
#  289 / 740
#  290 / 740
#  291 / 740
#  292 / 740
# error never an actor, adding value
#
#  292 / 741
# error never an actor, adding value
#
#  292 / 742
#  293 / 742
#  294 / 742
#  295 / 742
# error never an actor, adding value
#
#  295 / 743
# error never an actor, adding value
#
#  295 / 744
# error doesnt exist, adding value
#
#  295 / 745
#  296 / 745
# error doesnt exist, adding value
#
#  296 / 746
#  297 / 746
#  298 / 746
# error never an actor, adding value
#
#  298 / 747
# error never an actor, adding value
#
#  298 / 748
#  299 / 748
# error never an actor, adding value
#
#  299 / 749
# error never an actor, adding value
#
#  299 / 750
#  300 / 750
# error never an actor, adding value
#
#  300 / 751
#  301 / 751
#  302 / 751
#  303 / 751
#  304 / 751
# error never an actor, adding value
#
#  304 / 752
#  305 / 752
# error never an actor, adding value
#
#  305 / 753
# error never an actor, adding value
#
#  305 / 754
#  306 / 754
#  307 / 754
#  308 / 754
# error doesnt exist, adding value
#
#  308 / 755
#  309 / 755
# error doesnt exist, adding value
#
#  309 / 756
# error never an actor, adding value
#
#  309 / 757
#  310 / 757
#  311 / 757
# error never an actor, adding value
#
#  311 / 758
#  312 / 758
#  313 / 758
# error doesnt exist, adding value
#
#  313 / 759
# error never an actor, adding value
#
#  313 / 760
#  314 / 760
# error never an actor, adding value
#
#  314 / 761
#  315 / 761
#  316 / 761
# error doesnt exist, adding value
#
#  316 / 762
#  317 / 762
#  318 / 762
# error doesnt exist, adding value
#
#  318 / 763
# error doesnt exist, adding value
#
#  318 / 764
#  319 / 764
#  320 / 764
# error never an actor, adding value
#
#  320 / 765
#  321 / 765
#  322 / 765
#  323 / 765
#  324 / 765
#  325 / 765
# error never an actor, adding value
#
#  325 / 766
# error never an actor, adding value
#
#  325 / 767
#  326 / 767
#  327 / 767
# error doesnt exist, adding value
#  327 / 768
# error never an actor, adding value
#
#  327 / 769
# error never an actor, adding value
#
#  327 / 770
# error doesnt exist, adding value
#
#  327 / 771
#  328 / 771
# error doesnt exist, adding value
#
#  328 / 772
#  329 / 772
#  330 / 772
# error never an actor, adding value
#
#  330 / 773
#  331 / 773
# error never an actor, adding value
#
#  331 / 774
# error doesnt exist, adding value
#
#  331 / 775
#  332 / 775
# error never an actor, adding value
#
#  332 / 776
# error never an actor, adding value
#
#  332 / 777
# error doesnt exist, adding value
#
#  332 / 778
#  333 / 778
#  334 / 778
# error never an actor, adding value
#
#  334 / 779
# error doesnt exist, adding value
#
#  334 / 780
#  335 / 780
# error never an actor, adding value
#
#  335 / 781
# error never an actor, adding value
#
#  335 / 782
# error never an actor, adding value
#
#  335 / 783
# error never an actor, adding value
#
#  335 / 784
# error doesnt exist, adding value
#
#  335 / 785
#  336 / 785
#  337 / 785
# error doesnt exist, adding value
#
#  337 / 786
#  338 / 786
#  339 / 786
#  340 / 786
# error doesnt exist, adding value
#
#  340 / 787
# error never an actor, adding value
#
#  340 / 788
# error never an actor, adding value
#
#  340 / 789
# error doesnt exist, adding value
#
#  340 / 790
# error never an actor, adding value
#
#  340 / 791
# error never an actor, adding value
#
#  340 / 792
# error doesnt exist, adding value
#
#  340 / 793
#  341 / 793
# error never an actor, adding value
#
#  341 / 794
# error never an actor, adding value
#
#  341 / 795
# error doesnt exist, adding value
#
#  341 / 796
# error never an actor, adding value
#
#  341 / 797
# error doesnt exist, adding value
#
#  341 / 798
# error never an actor, adding value
#
#  341 / 799
#  342 / 799
# error never an actor, adding value
#
#  342 / 800
#  343 / 800
# error never an actor, adding value
#
#  343 / 801
#  344 / 801
#  345 / 801
# error never an actor, adding value
#
#  345 / 802
#  346 / 802
#  347 / 802
# error doesnt exist, adding value
#
#  347 / 803
# error never an actor, adding value
#
#  347 / 804
# error doesnt exist, adding value
#
#  347 / 805
#  348 / 805
#  349 / 805
#  350 / 805
# error never an actor, adding value
#
#  350 / 806
#  351 / 806
# error never an actor, adding value
#
#  351 / 807
# error never an actor, adding value
#
#  351 / 808
# error never an actor, adding value
#
#  351 / 809
#  352 / 809
# error never an actor, adding value
#
#  352 / 810
# error never an actor, adding value
#
#  352 / 811
# error never an actor, adding value
#
#  352 / 812
#  353 / 812
# error never an actor, adding value
#
#  353 / 813
# error never an actor, adding value
#
#  353 / 814
# error doesnt exist, adding value
#
#  353 / 815
# error never an actor, adding value
#
#  353 / 816
#  354 / 816
#  355 / 816
#  356 / 816
# error doesnt exist, adding value
#
#  356 / 817
# error never an actor, adding value
#
#  356 / 818
#  357 / 818
# error doesnt exist, adding value
#
#  357 / 819
#  358 / 819
# error doesnt exist, adding value
#
#  358 / 820
# error never an actor, adding value
#
#  358 / 821
#  359 / 821
# error doesnt exist, adding value
#
#  359 / 822
# error doesnt exist, adding value
#
#  359 / 823
#  360 / 823
# error never an actor, adding value
#
#  360 / 824
# error never an actor, adding value
#
#  360 / 825
# error never an actor, adding value
#
#  360 / 826
# error doesnt exist, adding value
#
#  360 / 827
# error never an actor, adding value
#
#  360 / 828
# error never an actor, adding value
#
#  360 / 829
# error doesnt exist, adding value
#
#  360 / 830
# error doesnt exist, adding value
#
#  360 / 831
#  361 / 831
# error doesnt exist, adding value
#
#  361 / 832
#  362 / 832
#  363 / 832
#  364 / 832
#  365 / 832
#  366 / 832
#  367 / 832
#  368 / 832
# error never an actor, adding value
#
#  368 / 833
# error never an actor, adding value
#
#  368 / 834
# error never an actor, adding value
#
#  368 / 835
# error doesnt exist, adding value
#
#  368 / 836
#  369 / 836
# error never an actor, adding value
#
#  369 / 837
#  370 / 837
# error never an actor, adding value
#
#  370 / 838
# error never an actor, adding value
#
#  370 / 839
# error never an actor, adding value
#
#  370 / 840
#  371 / 840
# error doesnt exist, adding value
#
#  371 / 841
#  372 / 841
# error doesnt exist, adding value
#
#  372 / 842
# error never an actor, adding value
#
#  372 / 843
#  373 / 843
#  374 / 843
#  375 / 843
# error never an actor, adding value
#
#  375 / 844
#  376 / 844
# error never an actor, adding value
#
#  376 / 845
# error doesnt exist, adding value
#
#  376 / 846
#  377 / 846
# error doesnt exist, adding value
#
#  377 / 847
# error doesnt exist, adding value
#
#  377 / 848
# error never an actor, adding value
#
#  377 / 849
#  378 / 849
#  379 / 849
#  380 / 849
#  381 / 849
#  382 / 849
#  383 / 849
#  384 / 849
# error doesnt exist, adding value
#
#  384 / 850
#  385 / 850
# error never an actor, adding value
#
#  385 / 851
#  386 / 851
# error never an actor, adding value
#
#  386 / 852
#  387 / 852
#  388 / 852
#  389 / 852
#  390 / 852
#  391 / 852
# error doesnt exist, adding value
#
#  391 / 853
#  392 / 853
#  393 / 853
# error never an actor, adding value
#
#  393 / 854
#  394 / 854
# error never an actor, adding value
#
#  394 / 855
#  395 / 855
# error doesnt exist, adding value
#
#  395 / 856
# error never an actor, adding value
#
#  395 / 857
# error never an actor, adding value
#
#  395 / 858
# error doesnt exist, adding value
#
#  395 / 859
# error never an actor, adding value
#
#  395 / 860
#  396 / 860
# error never an actor, adding value
#
#  396 / 861
#  397 / 861
# error doesnt exist, adding value
#
#  397 / 862
#  398 / 862
#  399 / 862
#  400 / 862
#  401 / 862
#  402 / 862
#  403 / 862
# error doesnt exist, adding value
#
#  403 / 863
#  404 / 863
#  405 / 863
#  406 / 863
#  407 / 863
#  408 / 863
#  409 / 863
#  410 / 863
#  411 / 863
# error never an actor, adding value
#
#  411 / 864
#  412 / 864
#  413 / 864
# error never an actor, adding value
#
#  413 / 865
# error doesnt exist, adding value
#
#  413 / 866
#  414 / 866
#  415 / 866
# error doesnt exist, adding value
#
#  415 / 867
# error never an actor, adding value
#
#  415 / 868
#  416 / 868
# error never an actor, adding value
#
#  416 / 869
# error never an actor, adding value
#
#  416 / 870
#  417 / 870
# error doesnt exist, adding value
#
#  417 / 871
# error never an actor, adding value
#
#  417 / 872
#  418 / 872
#  419 / 872
# error never an actor, adding value
#
#  419 / 873
# error doesnt exist, adding value
#
#  419 / 874
#  420 / 874
# error never an actor, adding value
#
#  420 / 875
#  421 / 875
#  422 / 875
#  423 / 875
# error never an actor, adding value
#
#  423 / 876
# error never an actor, adding value
#
#  423 / 877
#  424 / 877
#  425 / 877
#  426 / 877
#  427 / 877
# error never an actor, adding value
#
#  427 / 878
#  428 / 878
# error doesnt exist, adding value
#
#  428 / 879
#  429 / 879
#  430 / 879
# error never an actor, adding value
#
#  430 / 880
#  431 / 880
#  432 / 880
# error never an actor, adding value
#
#  432 / 881
# error never an actor, adding value
#
#  432 / 882
# error never an actor, adding value
#
#  432 / 883
# error doesnt exist, adding value
#
#  432 / 884
#  433 / 884
# error never an actor, adding value
#
#  433 / 885
#  434 / 885
# error never an actor, adding value
#
#  434 / 886
# error never an actor, adding value
#
#  434 / 887
#  435 / 887
#  436 / 887
#  437 / 887
# error doesnt exist, adding value
#
#  437 / 888
#  438 / 888
#  439 / 888
#  440 / 888
#  441 / 888
# error never an actor, adding value
#
#  441 / 889
#  442 / 889
# error never an actor, adding value
#
#  442 / 890
# error never an actor, adding value
#
#  442 / 891
#  443 / 891
#  444 / 891
#  445 / 891
#  446 / 891
#  447 / 891
# error doesnt exist, adding value
#
#  447 / 892
# error doesnt exist, adding value
#
#  447 / 893
#  448 / 893
# error never an actor, adding value
#
#  448 / 894
#  449 / 894
#  450 / 894
# error doesnt exist, adding value
#
#  450 / 895
#  451 / 895
#  452 / 895
#  453 / 895
# error doesnt exist, adding value
#
#  453 / 896
#  454 / 896
# error never an actor, adding value
#
#  454 / 897
# error never an actor, adding value
#
#  454 / 898
# error never an actor, adding value
#
#  454 / 899
# error never an actor, adding value
#
#  454 / 900
# error doesnt exist, adding value
#
#  454 / 901
#  455 / 901
# error never an actor, adding value
#
#  455 / 902
# error doesnt exist, adding value
#
#  455 / 903
# error doesnt exist, adding value
#
#  455 / 904
#  456 / 904
# error never an actor, adding value
#
#  456 / 905
# error never an actor, adding value
#
#  456 / 906
#  457 / 906
#  458 / 906
# error doesnt exist, adding value
#
#  458 / 907
#  459 / 907
# error doesnt exist, adding value
#  459 / 908
#  460 / 908
# error doesnt exist, adding value
#
#  460 / 909
#  461 / 909
#  462 / 909
#  463 / 909
#  464 / 909
#  465 / 909
#  466 / 909
# error doesnt exist, adding value
#
#  466 / 910
#  467 / 910
#  468 / 910
#  469 / 910
#  470 / 910
#  471 / 910
#  472 / 910
#  473 / 910
#  474 / 910
#  475 / 910
# error never an actor, adding value
#
#  475 / 911
#  476 / 911
# error doesnt exist, adding value
#
#  476 / 912
#  477 / 912
#  478 / 912
#  479 / 912
# error never an actor, adding value
#
#  479 / 913
#  480 / 913
#  481 / 913
# error never an actor, adding value
#
#  481 / 914
#  482 / 914
#  483 / 914
# error never an actor, adding value
#
#  483 / 915
# error doesnt exist, adding value
#
#  483 / 916
# error doesnt exist, adding value
#
#  483 / 917
# error never an actor, adding value
#
#  483 / 918
#  484 / 918
#  485 / 918
# error never an actor, adding value
#
#  485 / 919
# error never an actor, adding value
#
#  485 / 920
#  486 / 920
# error never an actor, adding value
#
#  486 / 921
# error never an actor, adding value
#
#  486 / 922
#  487 / 922
#  488 / 922
#  489 / 922
# error doesnt exist, adding value
#
#  489 / 923
# error never an actor, adding value
#
#  489 / 924
#  490 / 924
# error never an actor, adding value
#
#  490 / 925
# error doesnt exist, adding value
#
#  490 / 926
#  491 / 926
#  492 / 926
#  493 / 926
# error doesnt exist, adding value
#
#  493 / 927
#  494 / 927
#  495 / 927
#  496 / 927
# error never an actor, adding value
#
#  496 / 928
# error never an actor, adding value
#
#  496 / 929
# error never an actor, adding value
#
#  496 / 930
# error doesnt exist, adding value
#
#  496 / 931
# error doesnt exist, adding value
#
#  496 / 932
#  497 / 932
#  498 / 932
# error never an actor, adding value
#
#  498 / 933
#  499 / 933
# error doesnt exist, adding value
#
#  499 / 934
# error doesnt exist, adding value
#
#  499 / 935
# error never an actor, adding value
#
#  499 / 936
# error doesnt exist, adding value
#
#  499 / 937

# %%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
