# %%
import pandas as pd
import guest_star_class_01

# %%
guest_names = guest_star_class_01.guest_names
guest_ids = guest_star_class_01.guest_ids
id_to_name = guest_star_class_01.id_to_name
movies = guest_star_class_01.movies
stars = guest_star_class_01.stars

# %%
len(movies)/60
# Out:
# 65.38333333333334

# %%
movie_ids = []
for movie_id in movies:
    print(movie_id)
    movie_ids.append(movie_id)
# Out:
# 28560
# 37942
# 18930
# 128701
# 252440
# 43017
# 14580
# 52867
# 43228
# 197704
# 10633
# 127941
# 134834
# 353653
# 73313
# 120932
# 247443
# 665
# 53949
# 13909
# 348080
# 29244
# 170422
# 967
# 1403
# 3687
# 30345
# 22342
# 8095
# 25509
# 26516
# 27544
# 28297
# 28299
# 35392
# 35926
# 29260
# 36376
# 29967
# 43457
# 62804
# 44585
# 44592
# 16380
# 64456
# 46056
# 46399
# 17245
# 39943
# 48136
# 18019
# 49160
# 68191
# 18649
# 72529
# 72847
# 73550
# 85328
# 94641
# 140497
# 110742
# 130380
# 116767
# 147941
# 167769
# 194293
# 253963
# 242481
# 244868
# 43333
# 57849
# 260681
# 250216
# 107335
# 320853
# 148304
# 252061
# 220077
# 26205
# 48646
# 82203
# 114083
# 24751
# 68097
# 320915
# 4820
# 32569
# 320918
# 320919
# 137460
# 255086
# 320922
# 320923
# 281259
# 320925
# 98132
# 93062
# 385903
# 262056
# 433524
# 83814
# 69903
# 352177
# 166442
# 358411
# 71996
# 640
# 27972
# 28731
# 37461
# 43690
# 38456
# 64607
# 16905
# 80639
# 51787
# 120021
# 177639
# 252090
# 252894
# ...

# %%
df = pd.DataFrame(movies).T.set_index('movie').sort_values('count', ascending = False)
df
# Out:
#                                               count  \
# movie
# The Greatest Story Ever Told                      6
# Spartacus                                         6
# True Grit                                         5
# Batman                                            5
# The Cage                                          5
# Emperor of the North Pole                         5
# Scorpio                                           5
# To Kill a Mockingbird                             5
# Brute Corps                                       5
# Star Trek: Of Gods And Men                        5
# Julius Caesar                                     5
# One Man's Way                                     4
# The High and the Mighty                           4
# Soylent Green                                     4
# 40 Pounds of Trouble                              4
# Che!                                              4
# Cry Tough                                         4
# ...

# %%
guest_star_class_01.star_id_lookup(guest_ids[0]).movies
# Out:
# ['Naked Alibi',
#  'City of Fear',
#  'Murder by Contract',
#  'The 49th Man',
#  'The Lost Planet',
#  'Back Street',
#  'The Big Heat',
#  'Lord Love a Duck',
#  'I Was a Teenage Werewolf']

# %%
guest_star_class_01.movie_id_lookup(movie_ids[2]).stars
# Out:
# ['Joseph Mell', 'Kathie Browne', 'Phillip Pine']
