# %%
import pandas as pd
import os
import csv
import ast

import json
import requests
from time import sleep

# %%
class Guest_Star:
    """(name, id_num, movies, movie_ids) repository of data for star trek guest stars"""
    def __init__(self, name, id_num, movies, movie_ids):
        self.name = name
        self.id_num = id_num
        self.movies = movies
        self.movie_ids = movie_ids
        #could have count for number of episodes appeared in

# %%
class Movie:
    """(name, id_num, stars, star_ids, count) repository of data for star trek guest stars' movies"""
    def __init__(self, name, id_num, stars, star_ids, count):
        self.name = name
        self.id_num = id_num
        self.stars = stars
        self.star_ids = star_ids
        self.count = len(star_ids)

# %%
guest_names = ['Joseph Mell', 'Clegg Hoyt', 'Michael Dugan', 'John Hoyt', 'Malachi Throne', 'Leonard Mudie', 'Adam Roarke', 'Bob Johnson', 'Meg Wyllie', 'Susan Oliver', 'Peter Duryea', 'Georgia Schmidt', 'Jeffrey Hunter', 'Janos Prohaska', 'Laurel Goodwin', 'Francine Pyne', 'Vince Howard', 'Grace Lee Whitney', 'Bruce Watson', 'Jeanne Bal', 'Eddie Paskey', 'Alfred Ryder', 'Michael Zaslow', 'Bill Bradley', 'Ron Veto', 'Abraham Sofaer', 'Gene Roddenberry', 'Charles J. Stewart', 'Robert Walker, Jr.', 'Sally Kellerman', 'Robert H. Justman', 'Andrea Dromm', 'Lloyd Haynes', 'Paul Carr', 'Paul Fix', 'Gary Lockwood', 'Stewart Moss', 'Bruce Hyde', 'Edward Madden', 'Jim Goodwin', 'Jon Kowal', 'Gene Dynarski', 'Maggie Thrett', 'Susan Denberg', 'Karen Steele', 'Roger C. Carmel', 'Budd Albright', 'Vince Deadrick Sr.', 'Ted Cassidy', 'Michael Strong', 'Sherry Jackson', 'Harry Basch', 'David L. Ross', 'John Megna', 'Stephen McEveety', 'Michael J. Pollard', 'Kim Darby', 'Morgan Woodward', 'Susanne Wasson', 'James Gregory', 'Marianna Hill', 'Sean Morgan', 'Bruce Mars', 'Jeannie Malone', 'Anthony D. Call', 'Walker Edmiston', 'Vic Perrin', 'John Gabriel', 'Clint Howard', 'Hagan Beggs', 'Sean Kenney', 'Peter Duryea', 'Julie Parrish', 'William Sargent', 'Barbara Anderson', 'Arnold Moss', 'Barbara Baldavin', 'John Warburton', 'Paul Comi', 'Mark Lenard', 'Lawrence Montaigne', 'Marcia Brown', 'Emily Banks', 'Oliver McGowan', 'Shirley Bonne', 'Perry Lopez', 'Rees Vaughn', 'Peter Marko', 'Phyllis Douglas', 'John Crawford', 'Don Marshall', 'Venita Wolf', 'Richard Carlyle', 'Barbara Babcock', 'Michael Barrier', 'William Campbell', 'Grant Woods', 'James Farley', 'Jerry Ayres', 'Sean Kenney', 'Hal Lynch', 'John Winston', 'Ed Peck', 'Roger Perry', 'Alice Rawlings', 'Joan Marshall', 'Percy Rodriguez', 'Richard Webb', 'Elisha Cook Jr.', 'Karl Held', 'Charles Macaulay', 'Lev Mailer', 'Harry Townes', 'Morgan Farley', 'Jon
Dierkop', 5247: 'John Fiedler', 1307043: 'William Campbell', 1214912: 'Ed Reimers', 15992: 'William Schallert', 15995: 'Charlie Brill', 15993: 'Michael Pataki', 13786: 'Whit Bissell', 1947: 'Stanley Adams', 1190321: 'Bart La Rue', 16000: 'Mickey Morton', 1644782: 'Jane Ross', 15998: 'Joseph Ruskin', 14256: 'Dick Crockett', 15999: 'Steve Sandor', 98241: 'Angelique Pettyjohn', 14069: 'Vic Tayback', 16006: 'Lee Delano', 16004: 'Anthony Caruso', 52611: 'Dyanne Thorne', 1211920: 'Booker Bradshaw', 100418: 'Ned Romero', 165373: 'Michael Witney', 69763: 'Nancy Kovack', 16014: 'Diana Muldaur', 1220744: 'Ed McCready', 103034: 'Gilbert Green', 1637878: 'William Wintersole', 28027: 'Patrick Horgan', 124617: 'Richard Evans', 16019: 'Valora Noland', 16017: 'Skip Homeier', 16016: 'David Brian', 121041: 'Julie Cobb', 1183648: 'Carlton Byrd', 1768815: 'Lezlie Dalton', 143188: 'Robert Fortier', 12310: 'Warren Stevens', 16021: 'Barbara Bouchet', 1116836: 'Lloyd Kino', 1768816: 'Ed  McReady', 1754177: 'Irene Kelly', 12298: 'Roy Jenson', 16028: 'William Marshall', 1768817: 'Lois Jewell', 2782: 'Ian Wolfe', 16033: 'Rhodes Reason', 1214919: 'Gil Perkins', 16030: 'William Smithers', 16031: 'Logan Ramsey', 1563106: 'Sheila Leighton', 16047: 'Marj Dusay', 16051: 'Joanne Linville', 16052: 'Jack Donner', 131285: 'Sabrina Scharf', 16055: 'Richard Hale', 1214926: 'Rudy Solari', 1214909: 'Craig Huxley', 16060: 'Brian Tochi', 16059: 'Pamelyn Ferdin', 1436: 'Melvin Belli', 16063: 'David Frankham', 1768643: 'Bonnie Beecher', 16066: 'Rex Holman', 161405: 'Ron Soble', 16070: 'Bill Zuckert', 16071: 'Gregg Palmer', 34014: 'Charles Maxwell', 1212314: 'Susan Howard Chrane', 16074: 'Michael Ansara', 44687: 'Katherine Woodville', 16086: 'Liam Sullivan', 16085: 'Michael Dunn', 106664: 'Geoffrey Binney', 16090: 'Kathie Browne', 16089: 'Jason Evers', 151846: 'Willard Sage', 49939: 'Davis Roberts', 1244929: 'Alan Bergman', 1089676: 'Kathryn Hays', 151529: 'Jason Wingreen', 161297: 'Tony Young', 16097: 'Jay Robinson', 153606: 'Victor Brandt', 1214925: 'Lee Duncan', 82507: 'Dick Durock', 16096: 'France Nuyen', 16101: 'Steve Ihnat', 16102: 'Yvonne Craig', 16103: 'Keye Luke', 291: 'Frank Gorshin', 13871: 'Lou Antonio', 16106: 'David Hurst', 131274: 'Sharon Acker', 151402: 'Booker Bradshaw', 1213331: 'Kenneth Washington', 151511: 'Arthur Batanides', 16108: 'Lee Meriwether', 16112: 'Jan Shutan', 13259: 'James Daly', 1214934: 'Louise Sorel', 1637873: 'James Drake', 16120: 'Deborah Downey', 1579760: 'Mary Linda Rapelye', 16119: 'Charles Napier', 160816: 'Charlene Polite', 179145: 'Diana Ewing', 9811: 'Fred Williamson', 9596: 'Jeff Corey', 1016007: 'Bob Herron', 16126: 'Phillip Pine', 1214938: 'Lee Bergere', 16125: 'Barry Atwater', 84360: 'Anna Karen', 1214937: 'Kermit Murdock', 151695: 'Johnny Haymer', 16131: 'Mariette Hartley'}

# %%
#movies format is {'movie': movie['original_title'], 'movie_id': movie['id'], 'guest_names': [name, name, name] , 'guest_ids': [id_num, id_num, id_num], 'count': 3}
movies = {}
stars = {}
count = 0

api_key = '1bb6cfd646261b1acda61748ca2bb5a7'
id_lookup_dict = {}
# loops through each guest star
for index, id_num in enumerate(guest_ids):
#if True: # use with id_num below to test the Rogers error
    print(count, '/', len(guest_ids)-1, end = ' \t')
    #id_num = 83913 #for testing
    flag = True
    movie_list = []
    movie_id_list = []
    url = f'https://api.themoviedb.org/3/person/{id_num}/movie_credits?api_key={api_key}&language=en-US'
    dat = requests.get(url).json()
    sleep(.3)
    #print(json.dumps(dat , indent = 2, sort_keys= True))
    
    
    try:
        # each movie for which current guest star was listed as a cast member
        for movie in dat['cast']:
            #print(json.dumps(dat['cast, indent = 2, sort_keys= True))
            if movie['id'] not in movies:
                movies[movie['id']] = {'movie': movie['original_title'], 'movie_id': movie['id'], 'guest_names': [] , 'guest_ids': [], 'count': 0}
            
            movies[movie['id']]['guest_names'].append(id_to_name[id_num])
            movies[movie['id']]['guest_ids'].append(id_num)
            movies[movie['id']]['count'] += 1
            
            movie_list.append(movie['original_title'])
            movie_id_list.append(movie['id'])
            
            
    except KeyError:
        print(f'\nERROR - {url} \n {guest_ids.pop(index)}')       
        
        if id_num in id_to_name:
            del id_to_name[id_num]
        flag = False
        #Both Elizabeth Rogers and Peter Duryea errors fine they each now exist under two ids, one of which is correct the other popped above
    
    count += 1
    if flag:
        #otherwise id_to_name throws an error on call after del
        stars[id_num] = {'name': id_to_name[id_num], 'id_num': id_num, 'movies': movie_list , 'movie_ids': movie_id_list}
        id_lookup_dict[id_num] = Guest_Star(id_to_name[id_num], id_num, movie_list, movie_id_list)
        
#print(movies)
#print(stars)
# Out:
# 0 / 301 	1 / 301 	2 / 301 	3 / 301 	4 / 301 	5 / 301 	6 / 301 	7 / 301 	8 / 301 	9 / 301 	10 / 301 	11 / 301 	12 / 301 	13 / 301 	14 / 301 	15 / 301 	16 / 301 	17 / 301 	18 / 301 	19 / 301 	20 / 301 	21 / 301 	22 / 301 	23 / 301 	24 / 301 	25 / 301 	26 / 301 	27 / 301 	28 / 301 	29 / 301 	30 / 301 	31 / 301 	32 / 301 	33 / 301 	34 / 301 	35 / 301 	36 / 301 	37 / 301 	38 / 301 	39 / 301 	40 / 301 	41 / 301 	42 / 301 	43 / 301 	44 / 301 	45 / 301 	46 / 301 	47 / 301 	48 / 301 	49 / 301 	50 / 301 	51 / 301 	52 / 301 	53 / 301 	54 / 301 	55 / 301 	56 / 301 	57 / 301 	58 / 301 	59 / 301 	60 / 301 	61 / 301 	62 / 301 	63 / 301 	64 / 301 	65 / 301 	66 / 301 	67 / 301 	68 / 301 	69 / 301 	70 / 301 	71 / 301
# ERROR - https://api.themoviedb.org/3/person/1214892/movie_credits?api_key=1bb6cfd646261b1acda61748ca2bb5a7&language=en-US
#  1214892
# ...

# %%
#pd.DataFrame(stars).to_csv('Guest_Star_Data.csv')
#pd.DataFrame(movies).to_csv('Movie_Data.csv')
csv_columns = ['name', 'id_num', 'movies', 'movie_ids']
with open('Guest_Star_Data.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    for data in stars:
        writer.writerow(stars[data])

csv_columns =['movie', 'movie_id', 'guest_names', 'guest_ids', 'count']
with open('Movie_Data.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    for data in movies:
        writer.writerow(movies[data])

# %%
with open('id_to_name.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    for id_num in id_to_name:
        write_array = [id_num, id_to_name[id_num]]
        writer.writerow(write_array)

# %%
id_to_name = {}
guest_names = []
guest_ids = []
with open('id_to_name.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        id_to_name[row[0]] = row[1]
        guest_names.append(row[1])
        guest_ids.append(row[0])
id_to_name
# Out:
# {'100418': 'Ned Romero',
#  '1007561': 'Michael Forest',
#  '100799': 'George Sawaya',
#  '1016007': 'Bob Herron',
#  '10161': 'Richard Webb',
#  '101742': 'Leonard Mudie',
#  '102426': 'Billy Curtis',
#  '103034': 'Gilbert Green',
#  '106664': 'Geoffrey Binney',
#  '1089676': 'Kathryn Hays',
#  '1090742': 'Victor Lundin',
#  '10925': 'Torin Thatcher',
#  '1116836': 'Lloyd Kino',
#  '1124088': 'John Wheeler',
#  '117771': 'John Harmon',
#  '1183648': 'Carlton Byrd',
#  '118508': 'Tige Andrews',
#  '1190321': 'Bart La Rue',
#  '119245': 'Sherry Jackson',
#  '1209': 'Elinor Donahue',
#  '121041': 'Julie Cobb',
#  '1211920': 'Booker Bradshaw',
#  '1212314': 'Susan Howard Chrane',
#  '1212769': 'Walker Edmiston',
#  '1212973': 'Harry Basch',
#  '1213151': 'Lawrence Montaigne',
#  '1213153': 'Malachi Throne',
#  '1213331': 'Kenneth Washington',
#  '1214557': 'Marc Daniels',
#  '1214565': 'John Winston',
#  '1214877': 'Eddie Paskey',
#  '1214878': 'Bruce Hyde',
#  '1214880': 'Jeanne Bal',
# ...

# %%
movies = {}
with open('Movie_Data.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        movies[int(row['movie_id'])] = {'movie': row['movie'], 'movie_id': int(row['movie_id']), 'guest_names': ast.literal_eval(row['guest_names']), 'guest_ids': ast.literal_eval(row['guest_ids']), 'count': int(row['count'])}
movies
# Out:
# {28560: {'count': 1,
#   'guest_ids': [83913],
#   'guest_names': ['Joseph Mell'],
#   'movie': 'Naked Alibi',
#   'movie_id': 28560},
#  37942: {'count': 2,
#   'guest_ids': [83913, 16090],
#   'guest_names': ['Joseph Mell', 'Kathie Browne'],
#   'movie': 'City of Fear',
#   'movie_id': 37942},
#  18930: {'count': 3,
#   'guest_ids': [83913, 16090, 16126],
#   'guest_names': ['Joseph Mell', 'Kathie Browne', 'Phillip Pine'],
#   'movie': 'Murder by Contract',
#   'movie_id': 18930},
#  128701: {'count': 1,
#   'guest_ids': [83913],
#   'guest_names': ['Joseph Mell'],
#   'movie': 'The 49th Man',
#   'movie_id': 128701},
#  252440: {'count': 1,
#   'guest_ids': [83913],
#   'guest_names': ['Joseph Mell'],
#   'movie': 'The Lost Planet',
#   'movie_id': 252440},
#  43017: {'count': 2,
#   'guest_ids': [83913, 15978],
#   'guest_names': ['Joseph Mell', 'Charles Drake'],
#   'movie': 'Back Street',
#   'movie_id': 43017},
#  14580: {'count': 3,
#   'guest_ids': [83913, 15693, 15942],
# ...

# %%
stars = {}
with open('Guest_Star_Data.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        #print(row)
        stars[int(row['id_num'])] = {'name': row['name'], 'id_num': int(row['id_num']), 'movies': ast.literal_eval(row['movies']), 'movie_ids': ast.literal_eval(row['movie_ids'])}
stars
# Out:
# {246: {'id_num': 246,
#   'movie_ids': [62,
#    4934,
#    8745,
#    32825,
#    26643,
#    28569,
#    29861,
#    72111,
#    85942,
#    95354,
#    100279,
#    120773,
#    140354,
#    124807,
#    148655,
#    163683,
#    185063,
#    55537,
#    328226,
#    329621,
#    377578,
#    402719,
#    421229,
#    220327,
#    451806],
#   'movies': ['2001: A Space Odyssey',
#    'Firecreek',
#    "It Happened at the World's Fair",
#    'Wild in the Country',
#    'The Magic Sword',
#    'Splendor in the Grass',
#    'Bad Georgia Road',
#    'The Ghost of Flight 401',
#    'Model Shop',
#    'The Wild Pair',
#    'Manhunter',
#    'Project: Kill',
#    'Earth II',
#    'Las Vegas, 500 millones',
#    'The Incredible Journey of Doctor Meg Laurel',
#    'R.P.M.',
#    'Survival Zone',
#    'Night of the Scarecrow',
#    'Half Nelson',
#    'Unbelievable!!!!!',
#    'Bowie 2001 A Space Oddity',
#    'The Return of W. De Rijk',
#    'Stand Up and Be Counted',
# ...

# %%
movie_id_lookup_dict = {}
for id_num in movies:
    movie_id_lookup_dict[id_num] = Movie(movies[id_num]['movie'], id_num, movies[id_num]['guest_names'], movies[id_num]['guest_ids'], movies[id_num]['count'])
star_id_lookup_dict = {}
for id_num in stars:
    star_id_lookup_dict[id_num] = Guest_Star(stars[id_num]['name'], id_num, stars[id_num]['movies'], stars[id_num]['movie_ids'])

# %%
star_id_lookup_dict[100418].name
#movie_id_lookup_dict[37942].id_num
# Out:
# 'Ned Romero'

# %%
def star_id_lookup(id_num):
    return(star_id_lookup_dict[id_num])
def movie_id_lookup(id_num):
    return(movie_id_lookup_dict[id_num])

# %%
a = star_id_lookup(83913)
b = movie_id_lookup(37942)
a.name
b.stars
# Out:
# ['Joseph Mell', 'Kathie Browne']
